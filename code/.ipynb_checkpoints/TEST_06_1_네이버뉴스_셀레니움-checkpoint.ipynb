# %%
#동적 생성되는 data 크롤링
#Selenium 모듈 사용
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
import selenium
from selenium import webdriver

# %% [markdown]
# ### 관련 메서드
# - get(url) : url에 문서를 요청하고 응답을 받는 메서드
#
# #### 페이지 단일 element에 접근하는 메서드
# - find_element_by_name('html_name')
# - find_element_by_id('html_id')
# - find_element_by_xpath('패스경로') : 스크립트 실행 경로를 찾아 접근
#
#
# #### 페이지의 여러 element에 접근하는 메서드
# - find_element_by_class_selector('html slelctor')
# - find_element_by_class_name('html_class')
# - find_element_by_tag_name('html tag')
#
# #### Webdriver 객체 생성
# - driver = webdriver.Chrome(드라이버경로)
#
# #### 접근한 페이지 source 추출
# - html=driver.page_source

# %%
# 크롬 드라이버를 통한 네이버 접속

driver = webdriver.Chrome("./driver/chromedriver")
driver.get("https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=001&aid=0012587876")

# %%
driver.page_source # 전체 페이지 소스 로딩
# Out:
# '<html lang="ko" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36"><head>\n<meta charset="euc-kr">\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n<meta name="referrer" contents="always">\n<meta name="viewport" content="width=1106">\n<title>혼자 집에 둔 3살 딸 사망…시신 발견하고도 도망친 엄마 : 네이버 뉴스</title>\n\n\n\t\n\t\n\t\t\n\t\n\n\n\t\n\t\n\t\t\n\t\t\n\t\t\n\t\n\t\n\n<meta property="me2:post_tag" content="연합뉴스 : 네이버뉴스">\n<meta property="me2:category1" content="연합뉴스">\n<meta property="me2:category2" content="사회">\n<meta property="me2:image" content="">\n\n<meta property="og:title" content="혼자 집에 둔 3살 딸 사망…시신 발견하고도 도망친 엄마">\n<meta property="og:type" content="article">\n<meta property="og:url" content="https://news.naver.com/main/read.naver?mode=LSD&amp;mid=sec&amp;oid=001&amp;aid=0012587876&amp;sid1=001">\n<meta property="og:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png">\n<meta property="og:description" content="&quot;무서워 집 나왔다&quot;며 남자친구 집에 숨어 지내…구속영장 (인천=연합뉴스) 손현규 기자 = 3살 딸을 집에 혼자 두고 외출해 숨지게 한 혐의로 경찰에 체포된 30대 엄마는 사망한 딸을 발견하고도 시신을 방치한 채 남">\n<meta property="og:article:author" content="연합뉴스 | 네이버">\n\n<meta name="twitter:card" content="summary">\n<meta name="twitter:title" content="혼자 집에 둔 3살 딸 사망…시신 발견하고도 도망친 엄마">\n<meta name="twitter:site" content="네이버 뉴스">\n<meta name="twitter:creator" content="연합뉴스">\n<meta name="twitter:image" content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_200x200_20160804.png">\n<meta name="twitter:description" content="&quot;무서워 집 나왔다&quot;며 남자친구 집에 숨어 지내…구속영장 (인천=연합뉴스) 손현규 기자 = 3살 딸을 집에 혼자 두고 외출해 숨지게 한 혐의로 경찰에 체포된 30대 엄마는 사망한 딸을 발견하고도 시신을 방치한 채 남">\n\n\n\n\t\n\t\n\n<link rel="shortcut icon" type="image/x-icon" href="https://ssl.pstatic.net/static.news/image/news/2014/favicon/favicon.ico">\n\n\n\n\t\n\t\n\t\n\n\n\t\n\t\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/css/common.css">\n\t\t<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/css/news.css">\n\t\t\n\t\t\n\t\n\t\n\n\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.jindo.js" charset="euc-kr"></script>\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.jquery.js" charset="utf-8"></script>\n\n\n\n\n\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\n\t\t\n\t\n\t\n\n\n\n\n\t\n\t\t\n\t\t\n\t\t\t\n\t\t\n\t\n\n\n\n<script type="text/javascript">\ndocument.domain=\'naver.com\';\nvar _MAIN_NEWS_MENU_ID=\'shm\';\nvar _MAIN_NEWS_SECTION_ID=\'103\';\nvar ccsrv=\'cc.naver.com\';\nvar g_ssc=\'news.art\';\nwindow.nsc = g_ssc; \nvar gnb_service=\'news\';\nvar gnb_logout=encodeURIComponent(location.href);\nvar gnb_template=\'gnb_utf8\';\nvar gnb_brightness = 1;\nvar gnb_one_naver = 1;\nvar gnb_searchbox=\'on\';\nvar gnb_shortnick=\'on\';\n\nvar gnb_timestamp = "2021080915";\n</script>\n\n\n\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/news.service.js" charset="euc-kr"></script>\n\n<script type="text/javascript" src="https://ssl.pstatic.net/static.news/pnews/resources/20210804_211303/js/nil.news.js" charset="utf-8"></script>\n\n\n\n\n\n<meta http-equiv="X-UA-Compatible" content="IE=9; IE=8; IE=7">\n<script id="naver-splugin-sdk" type="text/javascript" charset="utf-8" src="https://ssl.pstatic.net/spi/js/release/ko_KR/splugin.js?20210809"></script><script type="text/javascript" charset="utf-8" src="https://news.like.naver.com/js/reaction/dist/reaction.min.js?20210809"></script><link charset="utf-8" type="text/css" rel="stylesheet" href="https://news.like.naver.com/static20210729151343/css/ssl/reaction/desktop/likeit_multi.c ...

# %%
like_list = driver.find_elements_by_css_selector("span.u_likeit_text._count.num")
like_num = [like.text for like in like_list ]
like_num
# Out:
# ['931']

# %%
#articleTitleCommentCount > span.lo_txt

# %%
rep_list = driver.find_elements_by_css_selector("span.lo_txt")
rep_num = [rep.text for rep in rep_list ]
rep_num
# Out:
# ['548']

# %%
# 전달된 뉴스  url의 기사에서 기사제목 기사입력시간을 반환하는 함수
def get_news_sub_info(url) :
    
    #1.전달된 url에 접속 후 응답객체 반환
    headers ={"User-Agent" : 
          "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}
    result = requests.get(url,headers=headers)
    
    #2.bs4 객체 생성
    bs_obj=BeautifulSoup(result.content,"html.parser")
    
    #3.필요 데이터 추출
    # 기사 제목 추출(태그객체)
    title =bs_obj.find(id='articleTitle')
    # 기사 입력시간 추출(태그객체)
    date_time = bs_obj.find("span",{"class":"t11"})
    
    #4.  webdriver  이용해서 좋아요 수를 반환
    driver = webdriver.Chrome("./driver/chromedriver")
    driver.get(url)
    # 좋아요 수
    like_list = driver.find_elements_by_css_selector("span.u_likeit_text._count.num")
    like_num = [like.text for like in like_list ]
    print(like_num)
    #댓글 수
    rep_list = driver.find_elements_by_css_selector("span.lo_txt")
    rep_num = [rep.text for rep in rep_list ]
    print(rep_num)
    
    #5.수집 데이터 dict로 구성 후 반환
    dict_sub ={}
    dict_sub["기사제목"] = title.text
    dict_sub["기사 입력 시간"]=date_time.text
    dict_sub['좋아요 수'] = like_num
    dict_sub['댓글 수'] =  rep_num
    
    return dict_sub

# %%
url = "https://news.naver.com"
headers={"User-Agent":
             "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}
result = requests.get(url,headers=headers)

bs_obj = BeautifulSoup(result.content,"html.parser")

#ul 태그 추출 : class:hdline_article_list
news_list = bs_obj.find("ul",{"class":"hdline_article_list"})
#모든 li 추출
lis = news_list.findAll("li")

#헤드라인뉴스 link 저장 - list
link_list=[]
for li in lis :
    a_tag = li.find("a")
    link_list.append("https://news.naver.com/"+a_tag["href"])
print(link_list)
# Out:
# ['https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=052&aid=0001624889', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=101&oid=277&aid=0004950846', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=469&aid=0000622628', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=102&oid=003&aid=0010654577', 'https://news.naver.com//main/read.naver?mode=LSD&mid=shm&sid1=100&oid=629&aid=0000099583']

# %%
for number in range(len(link_list)) :
    res = get_news_sub_info(link_list[number])
    print(res)
# Out:
# []
# ['']
# {'기사제목': "'사자명예훼손 혐의' 전두환...항소심 첫 출석", '기사 입력 시간': '2021.08.09. 오후 12:11', '좋아요 수': [], '댓글 수': ['']}
# []
# ['']
# {'기사제목': '대신증권, 라임펀드 최대 80% 배상안 수용 결정', '기사 입력 시간': '2021.08.09. 오후 2:06', '좋아요 수': [], '댓글 수': ['']}
# []
# ['']
# {'기사제목': '지난해 광복절 집회 주도 전광훈 목사 재판에', '기사 입력 시간': '2021.08.09. 오후 2:56', '좋아요 수': [], '댓글 수': ['']}
# []
# ['']
# {'기사제목': '생후 2주 아들 때려 살해…친부 징역 25년·친모 징역 7년', '기사 입력 시간': '2021.08.09. 오전 11:16', '좋아요 수': [], '댓글 수': ['']}
# []
# ['41']
# {'기사제목': '정의당 "이재용 가석방은 文대통령 정치적 부담 줄이려는 꼼수"', '기사 입력 시간': '2021.08.09. 오후 2:10', '좋아요 수': [], '댓글 수': ['41']}
