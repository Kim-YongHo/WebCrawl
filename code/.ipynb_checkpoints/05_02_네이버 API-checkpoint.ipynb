# %% [markdown]
# ## 네이버 검색 API 사용
#
# - blog 및 전문자료 호출 방법이 동일
# - bolg 검색만 대표로 예제 작성
#
#
# - 네이버 개발자 센터에 개발자 등록
#     - application 생성 (사용 API : 검색)
#     - client_id 와 client_secret 두 값을 생성해어 얻어와야 함

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import os
import sys
import urllib.request

# %%
## id와 key 변수에 저장

client_id = "STxhK23RTV2IJXshJ6F6"
client_secret = 'aeedTpXFb_'

# %%
## 검색어 설정 (utf-8로 인코딩)
## urllib.parse.quote
enc_text = urllib.parse.quote('강남역') ## quote를 통해 검색어 인코딩
enc_text
# Out:
# '%EA%B0%95%EB%82%A8%EC%97%AD'

# %% [markdown]
# ## url
# - 데이터 형태에 따라 2개의 url제공
# - https://openapi.naver.com/v1/search/blog.xml
# - https://openapi.naver.com/v1/search/blog.json (.json은 생략 가능)

# %%
url_base = 'https://openapi.naver.com/v1/search/blog?query=' #query=검색어

# %%
url = url_base + enc_text
url
# Out:
# 'https://openapi.naver.com/v1/search/blog?query=%EA%B0%95%EB%82%A8%EC%97%AD'

# %% [markdown]
# ## hearder 부착(id, key 전송)
# - urllib.request.Request(url) : 전송 객체 생성
# - Request.add_header(헤더) : 헤더 부착
# - request.urlopen(request 객첵) : 요청

# %%
request = urllib.request.Request(url)

# 헤더 추가 (request에 필요한 요소 추가)
request.add_header('X-Naver-Client-Id', client_id)
request.add_header('X-Naver-Client-Secret', client_secret)

# %%
# 요청 후 응답
response = urllib.request.urlopen(request)

# 서버가 전송한 응답코드 확인
rescode = response.getcode()
rescode
## 응답코드 200번 정상 출력
# Out:
# 200

# %%
if (rescode==200):
    response_body = response.read() # 전송된 검색 data 읽어오기
    #print(response_body) # encoding 된 결과가 넘어옴
    print(response_body.decode('utf-8'))
else:
    print('Error Code : ' + rescode)
# Out:
# {
# "lastBuildDate": "Mon, 09 Aug 2021 20:45:06 +0900",
# "total": 1742349,
# "start": 1,
# "display": 10,
# "items": [
# {
# "title": "<b>강남역</b> 데이트 맛집, 마마램",
# "link": "https:\/\/blog.naver.com\/scoroom?Redirect=Log&logNo=222456820669",
# "description": "캠핑장에서 돌아오고 남은 몇일의 여유를 즐기를 위해서 출동했다^^ <b>강남역</b> 데이트, 마마램 서울 강남구 도산대로 62길 11 (02-543-5310) 이번 캠핑에 양고기는 준비하지 않기도 했고, 양고기는 무엇보다 방문해서... ",
# "bloggername": "Sweet Cozy Room",
# "bloggerlink": "https://blog.naver.com/scoroom",
# "postdate": "20210804"
#
# },
# {
# "title": "재미가 있는 <b>강남역</b> 맛집 공유",
# "link": "https:\/\/blog.naver.com\/jung111hee?Redirect=Log&logNo=222455247595",
# "description": "감성타코 <b>강남역</b>점 감성그릴파히타 38000원 위치 : 서울 강남구 강남대로 406 지하1층 문의 : 02-565-8830 영업 : 11:30 - 22:00 마지막주문 21:00 제가 다녀온 감성타코는 <b>강남역</b>11번출구 바로 앞에 위치해있어요.... ",
# "bloggername": "맛집멋집",
# "bloggerlink": "https://blog.naver.com/jung111hee",
# "postdate": "20210803"
#
# },
# {
# "title": "<b>강남역</b> 스테이크 분위기 좋은 미도인",
# "link": "https:\/\/blog.naver.com\/tw01554?Redirect=Log&logNo=222459401543",
# "description": "<b>강남역</b> 스테이크 찾고 있다면 여기 어떨가 싶네용~ #<b>강남역</b>스테이크 #<b>강남역</b>대창덮밥 #<b>강남역</b>미도인 #미도인 #강남미도인 #미도인강남 #<b>강남역</b>스테이크맛집 #<b>강남역</b>대창덮밥맛집 #<b>강남역</b>가성비맛집... ",
# "bloggername": "헨2의 daily",
# "bloggerlink": "https://blog.naver.com/tw01554",
# "postdate": "20210806"
#
# },
# {
# "title": "재료가 좋은 삼겹살 <b>강남역</b> 고기집",
# "link": "https:\/\/blog.naver.com\/unique1028?Redirect=Log&logNo=222411292448",
# "description": "얼마 전 친구들과 모임 중 강남 일대에서 꽤 알아준다는 <b>강남역</b> 고기집에 다녀왔어요. 화로에 구워 육질이 우수한 돈육에 수제냉면까지, 무엇하나 부족함이 없었던 곳이랍니다. 강남구 역삼동 619-14 1층 봉우화로... ",
# "bloggername": "줄리다이어리♥",
# "bloggerlink": "https://blog.naver.com/unique1028",
# "postdate": "20210626"
#
# },
# {
# "title": "최고였던 <b>강남역</b> 고기집",
# "link": "https:\/\/blog.naver.com\/aq9999qa?Redirect=Log&logNo=222406466536",
# "description": "주소: 서울 강남구 역삼로3길 8 번호: 02-538-1588 이날 찾았던 고기집은 <b>강남역</b> 4번 출구에서 도보 5분 정도 거리에 위치해 있었는데요. 웅장한 단독건물에 상호가 크게 부착되어져 있어, 왠만해서는 못보고... ",
# "bloggername": "황혼의엘리제",
# "bloggerlink": "https://blog.naver.com/aq9999qa",
# "postdate": "20210622"
#
# },
# {
# "title": "인정했던 <b>강남역</b> 점심",
# "link": "https:\/\/blog.naver.com\/sitelove?Redirect=Log&logNo=222457129201",
# "description": "동료가 <b>강남역</b> 점심 장소로 괜찮은 특색 있는 장소를 추천해 줘서 다 같이 다녀올 수 있었어요. 저희가 점심에 방문해서 간단한 반주까지 하고 회사에 복귀하게 만들었던 식당은 반티엔야오 카오위예요. <b>강남역</b>... ",
# "bloggername": "주관적참견시점",
# "bloggerlink": "https://blog.naver.com/sitelove",
# "postdate": "20210804"
#
# },
# {
# "title": "극찬했던 <b>강남역</b> 돼지갈비 맛집",
# "link": "https:\/\/blog.naver.com\/seventhday?Redirect=Log&logNo=222416694910",
# "description": "얼마전 친구들과 저녁 약속이 있어서 검색으로 미리 알아둔 <b>강남역</b> 돼지갈비 맛집에서 식사했어요.... 강남 돼지갈비 맛집은 밖에서 구워 가져와 달라고 하면 그렇게 해주신다고 하니 참고하시면 좋을 것... ",
# "bloggername": "colortrip",
# "bloggerlink": "https://blog.naver.com/seventhday",
# "postdate": "20210702"
#
# },
# {
# "title": "합격점줬던 <b>강남역</b> 고기집",
# "link": "https:\/\/blog.naver.com\/miukitchen?Redirect=Log&logNo=222419120284",
# "description": "이날 찾아간 강남랭겹은 <b>강남역</b> 11번 출구에서 도보로 10분이 채 걸리지 않았어요. 코너 1층에 크게 걸려있는 삼겹살 사진과 유니크한 외관이라 멀리서도 눈에 확 들어왔네요. 이곳은 인기있는 사이드 메뉴로 구성... ",
# "bloggername": "초코퐁듀쿠키",
# "bloggerlink": "https://blog.naver.com/miukitchen",
# "postdate": "20210704"
#
# },
# {
# "title": "대만족했던 <b>강남역</b> 고기집",
# "link": "https:\/\/blog.naver.com\/smsha?Redirect=Log&logNo=222409477379",
# "description": "이날 갔던 백억하누 강남본점은 <b>강남역</b> 11번출구에서 걸어서 5분 정도 걸리더라구요. 멀리서 봐도 도심속의 정원같은 분위기로 꾸며져 있어 쉽게 눈에 띄었어요. 특히나 엄청나게 컸던 현수막으로 제일 유명한... ",
# "bloggername": "뚜시와 포포의 하이파이브",
# "bloggerlink": "https://blog.naver.com/smsha",
# "postdate": "20210625"
#
# },
# {
# "title": "<b>강남역</b> 데이트 _ 마마램 feat. 냄새가 1도 없는 양고기",
# "link": "https:\/\/blog.naver.com\/minahbb?Redirect=Log&logNo=222446265483",
# "description": "맞이하는 <b>강남역</b> 데이트 마마램 mama lamb 마마램은 8개월 미만의 프리미엄 양갈비만을 엄선해서... ㅠㅠ <b>강남역</b> 데이트 마마램에서 배추찜도 시켜보세요 이거 술안주 맞네 이렇게 한껏 올려서 한입에 먹습니다... ",
# "bloggername": "커몬커먼",
# "bloggerlink": "https://blog.naver.com/minahbb",
# "postdate": "20210727"
#
# }
# ]
# }

# %%
## requests 패키지 사용 - 코드를 좀 간단하게 변경 
#(반환되는 request의 응답객체는 json 형식으로 바로 변환이 가능 (바로 딕셔너리 사용가능))

import requests #서버접속
from urllib.parse import urlparse #한글처리
import urllib.parse

keyword = urllib.parse.quote("강남역")
url ="https://openapi.naver.com/v1/search/blog?query="
url_fin = url+keyword

#get()안에 url과 headers를 포함 할 수 있음
result = requests.get(url_fin,
      headers={"X-Naver-Client-Id":"STxhK23RTV2IJXshJ6F6",
               "X-Naver-Client-Secret":"aeedTpXFb_"})

json_obj = result.json() # 한글처리와 data 형식을 json으로 변경할 수 있음

# %%
# items라는 리스트로 모든 정보를 가지고 있음
json_obj
# Out:
# {'lastBuildDate': 'Mon, 09 Aug 2021 20:45:55 +0900',
#  'total': 1742349,
#  'start': 1,
#  'display': 10,
#  'items': [{'title': '<b>강남역</b> 데이트 맛집, 마마램',
#    'link': 'https://blog.naver.com/scoroom?Redirect=Log&logNo=222456820669',
#    'description': '캠핑장에서 돌아오고 남은 몇일의 여유를 즐기를 위해서 출동했다^^ <b>강남역</b> 데이트, 마마램 서울 강남구 도산대로 62길 11 (02-543-5310) 이번 캠핑에 양고기는 준비하지 않기도 했고, 양고기는 무엇보다 방문해서... ',
#    'bloggername': 'Sweet Cozy Room',
#    'bloggerlink': 'https://blog.naver.com/scoroom',
#    'postdate': '20210804'},
#   {'title': '재미가 있는 <b>강남역</b> 맛집 공유',
#    'link': 'https://blog.naver.com/jung111hee?Redirect=Log&logNo=222455247595',
#    'description': '감성타코 <b>강남역</b>점 감성그릴파히타 38000원 위치 : 서울 강남구 강남대로 406 지하1층 문의 : 02-565-8830 영업 : 11:30 - 22:00 마지막주문 21:00 제가 다녀온 감성타코는 <b>강남역</b>11번출구 바로 앞에 위치해있어요.... ',
#    'bloggername': '맛집멋집',
#    'bloggerlink': 'https://blog.naver.com/jung111hee',
#    'postdate': '20210803'},
#   {'title': '<b>강남역</b> 스테이크 분위기 좋은 미도인',
#    'link': 'https://blog.naver.com/tw01554?Redirect=Log&logNo=222459401543',
#    'description': '<b>강남역</b> 스테이크 찾고 있다면 여기 어떨가 싶네용~ #<b>강남역</b>스테이크 #<b>강남역</b>대창덮밥 #<b>강남역</b>미도인 #미도인 #강남미도인 #미도인강남 #<b>강남역</b>스테이크맛집 #<b>강남역</b>대창덮밥맛집 #<b>강남역</b>가성비맛집... ',
#    'bloggername': '헨2의 daily',
#    'bloggerlink': 'https://blog.naver.com/tw01554',
#    'postdate': '20210806'},
#   {'title': '재료가 좋은 삼겹살 <b>강남역</b> 고기집',
#    'link': 'https://blog.naver.com/unique1028?Redirect=Log&logNo=222411292448',
#    'description': '얼마 전 친구들과 모임 중 강남 일대에서 꽤 알아준다는 <b>강남역</b> 고기집에 다녀왔어요. 화로에 구워 육질이 우수한 돈육에 수제냉면까지, 무엇하나 부족함이 없었던 곳이랍니다. 강남구 역삼동 619-14 1층 봉우화로... ',
#    'bloggername': '줄리다이어리♥',
#    'bloggerlink': 'https://blog.naver.com/unique1028',
#    'postdate': '20210626'},
#   {'title': '최고였던 <b>강남역</b> 고기집',
#    'link': 'https://blog.naver.com/aq9999qa?Redirect=Log&logNo=222406466536',
#    'description': '주소: 서울 강남구 역삼로3길 8 번호: 02-538-1588 이날 찾았던 고기집은 <b>강남역</b> 4번 출구에서 도보 5분 정도 거리에 위치해 있었는데요. 웅장한 단독건물에 상호가 크게 부착되어져 있어, 왠만해서는 못보고... ',
#    'bloggername': '황혼의엘리제',
#    'bloggerlink': 'https://blog.naver.com/aq9999qa',
#    'postdate': '20210622'},
#   {'title': '인정했던 <b>강남역</b> 점심',
#    'link': 'https://blog.naver.com/sitelove?Redirect=Log&logNo=222457129201',
#    'description': '동료가 <b>강남역</b> 점심 장소로 괜찮은 특색 있는 장소를 추천해 줘서 다 같이 다녀올 수 있었어요. 저희가 점심에 방문해서 간단한 반주까지 하고 회사에 복귀하게 만들었던 식당은 반티엔야오 카오위예요. <b>강남역</b>... ',
#    'bloggername': '주관적참견시점',
#    'bloggerlink': 'https://blog.naver.com/sitelove',
#    'postdate': '20210804'},
#   {'title': '극찬했던 <b>강남역</b> 돼지갈비 맛집',
#    'link': 'https://blog.naver.com/seventhday?Redirect=Log&logNo=222416694910',
#    'description': '얼마전 친구들과 저녁 약속이 있어서 검색으로 미리 알아둔 <b>강남역</b> 돼지갈비 맛집에서 식사했어요.... 강남 돼지갈비 맛집은 밖에서 구워 가져와 달라고 하면 그렇게 해주신다고 하니 참고하시면 좋을 것... ',
#    'bloggername': 'colortrip',
#    'bloggerlink': 'https://blog.naver.com/seventhday',
#    'postdate': '20210702'},
#   {'title': '합격점줬던 <b>강남역</b> 고기집',
#    'link': 'https://blog.naver.com/miukitchen?Redirect=Log&logNo=222419120284',
#    'description': '이날 찾아간 강남랭겹은 <b>강남역</b> 11번 출구에서 도보로 10분이 채 걸리지 않았어요. 코너 1층에 크게 걸려있는 삼겹살 사진과 유니크한 외관이라 멀리서도 눈에 확 들어왔네요. 이곳은 인기있는 사이드 메뉴로 구성... ',
#    'bloggername': '초코퐁듀쿠키',
#    'bloggerlink': 'https://blog.naver.com/miukitchen',
#    'postdate': '20210704'},
#   {'title': '대만족했던 <b>강남역</b> 고기집',
#    'link': 'https://blog.naver.com/smsha?Redirect=Log&logNo=222409477379',
#    'description': '이날 갔던 백억하누 강남본점은 <b>강남역</b> 11번출구에서 걸어서 5분 정도 걸리더라구요. 멀리서 봐도 도심속의 정원같은 분위기로 꾸며져 있어 쉽게 눈에 띄었어요. 특히나 엄청나게 컸던 현수막으로 제일 유명한... ',
#    'bloggername': '뚜시와 포포의 하이파이브',
#    'bloggerlink': 'https://blog.naver.com/smsha',
#    'postdate': '20210625'},
#   {'title': '<b>강남역</b> 데이트 _ 마마램 feat. 냄새가 1도 없는 양고기',
#    'link': 'https://blog.naver.com/minahbb?Redirect=Log&logNo=222446265483',
#    'description': '맞이하는 <b>강남역</b> 데이트 마마램 mama lamb 마마램은 8개월 미만의 프리미엄 양갈비만을 엄선해서... ㅠㅠ <b>강남역</b> 데이트 마마램에서 배추찜도 시켜보세요 이거 술안주 맞네 이렇게 한껏 올려서 한입에 먹습니다... ',
#    'bloggername': '커몬커먼',
#    'bloggerlink': 'https://blog.naver.com/minahbb',
#    'postdate': '20210727'}]}

# %%
print(json_obj["lastBuildDate"])
print(json_obj['total'])
print(json_obj['start'])
print(json_obj['display'])
# Out:
# Mon, 09 Aug 2021 20:45:55 +0900
# 1742349
# 1
# 10

# %%
## json data 추출 : dict 처럼 변수 [key]
json_obj['items']
# Out:
# [{'title': '<b>강남역</b> 데이트 맛집, 마마램',
#   'link': 'https://blog.naver.com/scoroom?Redirect=Log&logNo=222456820669',
#   'description': '캠핑장에서 돌아오고 남은 몇일의 여유를 즐기를 위해서 출동했다^^ <b>강남역</b> 데이트, 마마램 서울 강남구 도산대로 62길 11 (02-543-5310) 이번 캠핑에 양고기는 준비하지 않기도 했고, 양고기는 무엇보다 방문해서... ',
#   'bloggername': 'Sweet Cozy Room',
#   'bloggerlink': 'https://blog.naver.com/scoroom',
#   'postdate': '20210804'},
#  {'title': '재미가 있는 <b>강남역</b> 맛집 공유',
#   'link': 'https://blog.naver.com/jung111hee?Redirect=Log&logNo=222455247595',
#   'description': '감성타코 <b>강남역</b>점 감성그릴파히타 38000원 위치 : 서울 강남구 강남대로 406 지하1층 문의 : 02-565-8830 영업 : 11:30 - 22:00 마지막주문 21:00 제가 다녀온 감성타코는 <b>강남역</b>11번출구 바로 앞에 위치해있어요.... ',
#   'bloggername': '맛집멋집',
#   'bloggerlink': 'https://blog.naver.com/jung111hee',
#   'postdate': '20210803'},
#  {'title': '<b>강남역</b> 스테이크 분위기 좋은 미도인',
#   'link': 'https://blog.naver.com/tw01554?Redirect=Log&logNo=222459401543',
#   'description': '<b>강남역</b> 스테이크 찾고 있다면 여기 어떨가 싶네용~ #<b>강남역</b>스테이크 #<b>강남역</b>대창덮밥 #<b>강남역</b>미도인 #미도인 #강남미도인 #미도인강남 #<b>강남역</b>스테이크맛집 #<b>강남역</b>대창덮밥맛집 #<b>강남역</b>가성비맛집... ',
#   'bloggername': '헨2의 daily',
#   'bloggerlink': 'https://blog.naver.com/tw01554',
#   'postdate': '20210806'},
#  {'title': '재료가 좋은 삼겹살 <b>강남역</b> 고기집',
#   'link': 'https://blog.naver.com/unique1028?Redirect=Log&logNo=222411292448',
#   'description': '얼마 전 친구들과 모임 중 강남 일대에서 꽤 알아준다는 <b>강남역</b> 고기집에 다녀왔어요. 화로에 구워 육질이 우수한 돈육에 수제냉면까지, 무엇하나 부족함이 없었던 곳이랍니다. 강남구 역삼동 619-14 1층 봉우화로... ',
#   'bloggername': '줄리다이어리♥',
#   'bloggerlink': 'https://blog.naver.com/unique1028',
#   'postdate': '20210626'},
#  {'title': '최고였던 <b>강남역</b> 고기집',
#   'link': 'https://blog.naver.com/aq9999qa?Redirect=Log&logNo=222406466536',
#   'description': '주소: 서울 강남구 역삼로3길 8 번호: 02-538-1588 이날 찾았던 고기집은 <b>강남역</b> 4번 출구에서 도보 5분 정도 거리에 위치해 있었는데요. 웅장한 단독건물에 상호가 크게 부착되어져 있어, 왠만해서는 못보고... ',
#   'bloggername': '황혼의엘리제',
#   'bloggerlink': 'https://blog.naver.com/aq9999qa',
#   'postdate': '20210622'},
#  {'title': '인정했던 <b>강남역</b> 점심',
#   'link': 'https://blog.naver.com/sitelove?Redirect=Log&logNo=222457129201',
#   'description': '동료가 <b>강남역</b> 점심 장소로 괜찮은 특색 있는 장소를 추천해 줘서 다 같이 다녀올 수 있었어요. 저희가 점심에 방문해서 간단한 반주까지 하고 회사에 복귀하게 만들었던 식당은 반티엔야오 카오위예요. <b>강남역</b>... ',
#   'bloggername': '주관적참견시점',
#   'bloggerlink': 'https://blog.naver.com/sitelove',
#   'postdate': '20210804'},
#  {'title': '극찬했던 <b>강남역</b> 돼지갈비 맛집',
#   'link': 'https://blog.naver.com/seventhday?Redirect=Log&logNo=222416694910',
#   'description': '얼마전 친구들과 저녁 약속이 있어서 검색으로 미리 알아둔 <b>강남역</b> 돼지갈비 맛집에서 식사했어요.... 강남 돼지갈비 맛집은 밖에서 구워 가져와 달라고 하면 그렇게 해주신다고 하니 참고하시면 좋을 것... ',
#   'bloggername': 'colortrip',
#   'bloggerlink': 'https://blog.naver.com/seventhday',
#   'postdate': '20210702'},
#  {'title': '합격점줬던 <b>강남역</b> 고기집',
#   'link': 'https://blog.naver.com/miukitchen?Redirect=Log&logNo=222419120284',
#   'description': '이날 찾아간 강남랭겹은 <b>강남역</b> 11번 출구에서 도보로 10분이 채 걸리지 않았어요. 코너 1층에 크게 걸려있는 삼겹살 사진과 유니크한 외관이라 멀리서도 눈에 확 들어왔네요. 이곳은 인기있는 사이드 메뉴로 구성... ',
#   'bloggername': '초코퐁듀쿠키',
#   'bloggerlink': 'https://blog.naver.com/miukitchen',
#   'postdate': '20210704'},
#  {'title': '대만족했던 <b>강남역</b> 고기집',
#   'link': 'https://blog.naver.com/smsha?Redirect=Log&logNo=222409477379',
#   'description': '이날 갔던 백억하누 강남본점은 <b>강남역</b> 11번출구에서 걸어서 5분 정도 걸리더라구요. 멀리서 봐도 도심속의 정원같은 분위기로 꾸며져 있어 쉽게 눈에 띄었어요. 특히나 엄청나게 컸던 현수막으로 제일 유명한... ',
#   'bloggername': '뚜시와 포포의 하이파이브',
#   'bloggerlink': 'https://blog.naver.com/smsha',
#   'postdate': '20210625'},
#  {'title': '<b>강남역</b> 데이트 _ 마마램 feat. 냄새가 1도 없는 양고기',
#   'link': 'https://blog.naver.com/minahbb?Redirect=Log&logNo=222446265483',
#   'description': '맞이하는 <b>강남역</b> 데이트 마마램 mama lamb 마마램은 8개월 미만의 프리미엄 양갈비만을 엄선해서... ㅠㅠ <b>강남역</b> 데이트 마마램에서 배추찜도 시켜보세요 이거 술안주 맞네 이렇게 한껏 올려서 한입에 먹습니다... ',
#   'bloggername': '커몬커먼',
#   'bloggerlink': 'https://blog.naver.com/minahbb',
#   'postdate': '20210727'}]

# %%
for item in json_obj['items']:
    print(item.keys())
# Out:
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])
# dict_keys(['title', 'link', 'description', 'bloggername', 'bloggerlink', 'postdate'])

# %%
for item in json_obj['items']:
    print(len(item.keys()))
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6

# %%
# title 제목 추출
for item in json_obj['items']:
    print(item['title'])
# Out:
# <b>강남역</b> 데이트 맛집, 마마램
# 재미가 있는 <b>강남역</b> 맛집 공유
# <b>강남역</b> 스테이크 분위기 좋은 미도인
# 재료가 좋은 삼겹살 <b>강남역</b> 고기집
# 최고였던 <b>강남역</b> 고기집
# 인정했던 <b>강남역</b> 점심
# 극찬했던 <b>강남역</b> 돼지갈비 맛집
# 합격점줬던 <b>강남역</b> 고기집
# 대만족했던 <b>강남역</b> 고기집
# <b>강남역</b> 데이트 _ 마마램 feat. 냄새가 1도 없는 양고기

# %%
# title 제목 추출
# 불용어 제거 (불필요한 내용)
for item in json_obj['items']:
    print(item['title'].replace('<b>','').replace('</b>',''))
# Out:
# 강남역 데이트 맛집, 마마램
# 재미가 있는 강남역 맛집 공유
# 강남역 스테이크 분위기 좋은 미도인
# 재료가 좋은 삼겹살 강남역 고기집
# 최고였던 강남역 고기집
# 인정했던 강남역 점심
# 극찬했던 강남역 돼지갈비 맛집
# 합격점줬던 강남역 고기집
# 대만족했던 강남역 고기집
# 강남역 데이트 _ 마마램 feat. 냄새가 1도 없는 양고기

# %%
## 검색 결과 100개로 늘리기

keyword = "강남역"
url ="https://openapi.naver.com/v1/search/blog?query="
url_fin = url + keyword + '&display=100'

result = requests.get(url_fin,
      headers={"X-Naver-Client-Id":"STxhK23RTV2IJXshJ6F6",
               "X-Naver-Client-Secret":"aeedTpXFb_"})

# %%
#items를 제외한 4개의 key value 추출
json_obj = result.json()
print(json_obj["lastBuildDate"])
print(json_obj['total']) #전체 검색 개수
print(json_obj['start']) #반환되는 data의 시작 값, 기본 1
print(json_obj['display'])#반환되는 검색 data 개수, 기본 10
# Out:
# Mon, 09 Aug 2021 20:51:50 +0900
# 1742349
# 1
# 100

# %% [markdown]
# ## 연습문제

# %%
## 원하는 검색어를 설정한 후 
## 글제목, 설명, 세부링크, 블로거명, 블로그 주소, 생성날짜를 추출해서 df로 저장
## 200개 data를 저장

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
keyword = urllib.parse.quote("올림픽")
url ="https://openapi.naver.com/v1/search/blog?query="
url_1 = url + keyword + "&display=100&start="

# %%
import pandas as pd
search_df = pd.DataFrame()

# %%
for i in range(2): #url 200개를 가져와서 range = 2 (100개씩 가져올 수 있음)
    start = i*100+1
    url_fin = url_1 + str(start)
#     print(url_fin)
    result = requests.get(url_fin, 
                          headers={"X-Naver-Client-Id":"STxhK23RTV2IJXshJ6F6", 
                                   "X-Naver-Client-Secret":"aeedTpXFb_"})
    
    json_obj = result.json()
    
    # 데이터 들어오는 확인하기 위한 코드
    print(json_obj["lastBuildDate"])
    print(json_obj['total'])
    print(json_obj['start'])
    print(json_obj['display'])
    
    for item in json_obj["items"] :
        item_dict = {}
        item_dict["title"] = item['title'].replace("<b>","").replace("</b>","")
        item_dict["link"] = item['link']
        item_dict["description"] = item['description'].replace("<b>","").replace("</b>","")
        item_dict["bloggername"] = item['bloggername'].replace("<b>","").replace("</b>","")
        item_dict["bloggerlink"] = item['bloggerlink']
        item_dict["p_Date"] = item["postdate"]
        search_df = search_df.append(item_dict,ignore_index=True)
# Out:
# Mon, 09 Aug 2021 20:52:11 +0900
# 3012650
# 1
# 100
# Mon, 09 Aug 2021 20:52:11 +0900
# 3012650
# 101
# 100

# %%
json_obj
# Out:
# {'lastBuildDate': 'Mon, 09 Aug 2021 20:52:11 +0900',
#  'total': 3012650,
#  'start': 101,
#  'display': 100,
#  'items': [{'title': '한국 <b>올림픽</b>야구 동메달 결정전 예상(한국 VS 도미니카)',
#    'link': 'https://blog.naver.com/peterfine?Redirect=Log&logNo=222460518074',
#    'description': '<b>올림픽</b> 야구 대표팀은 일본과 미국에 연달아 패하며 도미니카와의 동메달 결정전에 나선다. 한국 대표팀 선수 개개인이 확실히 일본이나 미국에 비해 경쟁력이 떨어져 예상했던 결과다. 한국은 역대 <b>올림픽</b>에서... ',
#    'bloggername': '사색하는 자유(Truth will set you free)',
#    'bloggerlink': 'https://blog.naver.com/peterfine',
#    'postdate': '20210807'},
#   {'title': '김연경선수의 월드클래스 - <b>올림픽</b> 여자배구 4강팀 주장들과... ',
#    'link': 'https://blog.naver.com/enikia?Redirect=Log&logNo=222462227989',
#    'description': '국제 배구연맹 FIVB는 이번 <b>올림픽</b>의 가장 상징적인 포옹 MOST ICONIC HUG AT Tokyo2020이라고 표현. 동메달... 이렇게 한국 김연경, 브라질 나탈리, 세르비아 보스코비치, 미국 라슨 선수는 도쿄 <b>올림픽</b> 4강에... ',
#    'bloggername': '니키연구소',
#    'bloggerlink': 'https://blog.naver.com/enikia',
#    'postdate': '20210808'},
#   {'title': '2020도쿄<b>올림픽</b> SBS엔딩 ‘조용필-고독한 러너’',
#    'link': 'https://blog.naver.com/5025235?Redirect=Log&logNo=222462181253',
#    'description': '도쿄2020<b>올림픽</b> 유일한 굿즈(?)는 내 인생 첫 신용카드인 라인페이비자크레딧인데 카드 유효기간이 2025년까지라 2024파리<b>올림픽</b> 끝나고 나서까지도 쓸판..ㅋㅋㅋ 1년 좀 밖에 안됐는데 벌써 카드 표면이... ',
#    'bloggername': '오래된 노래',
#    'bloggerlink': 'https://blog.naver.com/5025235',
#    'postdate': '20210808'},
#   {'title': '<b>올림픽</b>, 중국의 주력 종목 배드민턴을 알아보자!',
#    'link': 'https://blog.naver.com/chinasisa?Redirect=Log&logNo=222451151946',
#    'description': '이 중 羽毛球[yǔ máo qiú], 배드민턴은 탁구와 더불어 이번 도쿄<b>올림픽</b>에서 중국이 우승을 노리고 있는... <b>올림픽</b> / 세계선수권대회 국가별 메달 수 (출처: wikipedia.org) 세계배드민턴연맹은 <b>올림픽</b>을 포함해... ',
#    'bloggername': '시사중국어사 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/chinasisa',
#    'postdate': '20210730'},
#   {'title': '역대 <b>올림픽</b> 야구 성적 서울 애틀란타 시드니 베이징 도쿄',
#    'link': 'https://blog.naver.com/justmeet?Redirect=Log&logNo=222461658604',
#    'description': '도쿄 <b>올림픽</b> 동메달 결정전, 한국 야구 대표팀이 도미니카에 역전을 허용하며 메달 획득에 실패했다. 혹시나 했는데, 설마 했는데.. 현실이 됐다. 야구가 <b>올림픽</b>에 정식 종목으로 채택된 시점은 1992년... ',
#    'bloggername': '지식창고(知識倉庫)',
#    'bloggerlink': 'https://blog.naver.com/justmeet',
#    'postdate': '20210808'},
#   {'title': '도쿄<b>올림픽</b> 축구 일정 한국 멕시코 전적 선수명단',
#    'link': 'https://blog.naver.com/dongi0508?Redirect=Log&logNo=222451030302',
#    'description': '도쿄<b>올림픽</b> 축구 일정 한국 멕시코 전적 선수명단 드디어 7월31일 토요일. 한국시각으로 저녁 20시.... 위에 이미지는 대한민국 국가대표팀 도쿄<b>올림픽</b> 축구 일정이다. 8강에 오른 다른 팀들 보면 장난... ',
#    'bloggername': 'Der Sinn des Lebens',
#    'bloggerlink': 'https://blog.naver.com/dongi0508',
#    'postdate': '20210730'},
#   {'title': '2020 도쿄 <b>올림픽</b> 마라톤 일정 및 오주한 메달 가능성은?',
#    'link': 'https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222458416417',
#    'description': '대한민국은 육상의 불모지인데요, 이번 <b>올림픽</b>에도 사실 메달은 어렵고 예선 통과해서 결선 진출이... 그나마 대한민국이 <b>올림픽</b>에서 비벼볼만한 육상종목이 마라톤 인데요 고 손기정옹이 일장기를 달고... ',
#    'bloggername': '미스터모모 컬렉션',
#    'bloggerlink': 'https://blog.naver.com/mr_mo_mo',
#    'postdate': '20210805'},
#   {'title': '도쿄 <b>올림픽</b> 메달 순위와 현재 상황',
#    'link': 'https://blog.naver.com/kcallda?Redirect=Log&logNo=222459076997',
#    'description': '도쿄<b>올림픽</b>이 어느덧 중반부를 향해 달려가고 있네요. 여러분은 본방사수하면서 열심히 응원하고... 출처 : 연합뉴스 그런데 모든 경기를 보다보니까 유독 이번 <b>올림픽</b>에서 변수가 꽤 많은 것 같다는 생각이... ',
#    'bloggername': 'Beyond Expectations',
#    'bloggerlink': 'https://blog.naver.com/kcallda',
#    'postdate': '20210806'},
#   {'title': '도쿄<b>올림픽</b> 여자배구 중계 (2020)',
#    'link': 'https://blog.naver.com/tubetint?Redirect=Log&logNo=222459660702',
#    'description': '안녕하세요 2020 도쿄 <b>올림픽</b>은 매경기 감동의 순간으로 역사적인 장면으로 남겨질 것 같습니다. 축구계의 메신이 있다면 배구계의 연경신 오늘 다시한번 역사적인 <b>올림픽</b> 배구 중계 일정을 감상하시기... ',
#    'bloggername': '뷰티 스토리 텔러',
#    'bloggerlink': 'https://blog.naver.com/tubetint',
#    'postdate': '20210806'},
#   {'title': '도쿄 <b>올림픽</b> 여자배구 4강 일정 및 시간, 배구 준결승 대진표',
#    'link': 'https://blog.naver.com/july7th73?Redirect=Log&logNo=222458188552',
#    'description': '김연경이 이끄는 <b>올림픽</b> 여자배구 대진표와 남은 4강 일정을 알아보겠습니다. 터키를 잡고 준결승에 오른 우리나라는 금요일 밤 9시에 브라질과 만나는데요~ 퇴근하고 <b>올림픽</b>을 즐기기 가장 좋은 불금의... ',
#    'bloggername': '수연아빠의 야구장 출동 (개포맘모스)',
#    'bloggerlink': 'https://blog.naver.com/july7th73',
#    'postdate': '20210806'},
#   {'title': '[잡담] 만화로 익힌 지식들로 <b>올림픽</b> 시청 중.',
#    'link': 'https://blog.naver.com/wmh0107?Redirect=Log&logNo=222458157955',
#    'description': 'Free!, 하이큐!!, 엑시트 핑퐁 스포츠를 그렇게 좋아하지 않지만, 이번 <b>올림픽</b>에서 관심 가는 경기는 몇... 스포츠 클라이밍은 지난 <b>올림픽</b> 때, 없었던 거 같은데…? 영화 엑시트 보고 나서 관심이 생겼다. 스포츠... ',
#    'bloggername': '너와 나 그리고 홀리데이',
#    'bloggerlink': 'https://blog.naver.com/wmh0107',
#    'postdate': '20210805'},
#   {'title': '[2020 도쿄<b>올림픽</b>] 정확하게 빠르게 부드럽게 : 가라테',
#    'link': 'https://blog.naver.com/sports_7330?Redirect=Log&logNo=222457722253',
#    'description': '이번 도쿄<b>올림픽</b>에 신설되어, 단 1명의 국가대표가 출전하는 종목이 있습니다. 하지만 도쿄<b>올림픽</b> 한정으로 채택된 종목이라, 해당 종목의 <b>올림픽</b> 출전은 처음이자 마지막이 될 수도 있는 바로 그 종목.... ',
#    'bloggername': '대한체육회 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/sports_7330',
#    'postdate': '20210805'},
#   {'title': '[<b>올림픽</b> 배구] 김연경의 눈물과 강백호의 질겅질겅',
#    'link': 'https://blog.naver.com/shalacho?Redirect=Log&logNo=222461564551',
#    'description': '사진- SBS <b>올림픽</b> 여자배구 국가 대표팀의 여정이 모두 끝났습니다. 목에 무게감은 없지만, 어깨를... 마지막 <b>올림픽</b>을 마친 김연경 선수는 결국 눈시울이 붉어졌습니다. 괜찮다, 후회 없는 경기를 했다고... ',
#    'bloggername': '보미로그',
#    'bloggerlink': 'https://blog.naver.com/shalacho',
#    'postdate': '20210808'},
#   {'title': '<b>올림픽</b>금메달연금 한번에 정리',
#    'link': 'https://blog.naver.com/dreamseller7?Redirect=Log&logNo=222454052747',
#    'description': '대한민국을 위해 자신과의 싸움에서 이긴 <b>올림픽</b> 메달리스트들에게 주어지는 금메달 연금은 과연 얼마일까? <b>올림픽</b>금메달연금 어려운 환경 속에서도 대한민국의 국기를 가슴에 달고 열심히 싸워주고... ',
#    'bloggername': '이만블리와 함께 경제•부동산 쉽게 알기',
#    'bloggerlink': 'https://blog.naver.com/dreamseller7',
#    'postdate': '20210802'},
#   {'title': '도쿄 <b>올림픽</b> 여자 배구 일정 4강 언제',
#    'link': 'https://blog.naver.com/atssa60?Redirect=Log&logNo=222458728283',
#    'description': '도쿄<b>올림픽</b> 여자 배구 일정 4강 언제 안녕하세요 앤트리입니다 © kfdias, 출처 Unsplash 요즘 2020 도쿄 <b>올림픽</b>이 한창 열리고 있습니다 종목을 불문하고 한국이 출전하는 경기는 돌리던 채널도 멈추고... ',
#    'bloggername': '초보캠퍼의 가성비 캠핑',
#    'bloggerlink': 'https://blog.naver.com/atssa60',
#    'postdate': '20210806'},
#   {'title': '도쿄<b>올림픽</b> 응원  댓글 달기 블로그 이벤트 EVENT',
#    'link': 'https://blog.naver.com/incheontogi?Redirect=Log&logNo=222439635517',
#    'description': '도쿄<b>올림픽</b>이 오늘부터 개최됩니다. 도쿄<b>올림픽</b> 개최를 맞이해, 응원 댓글 달기 블로그 이벤트를 진행합니다! 이번 <b>올림픽</b> 공식명칭은 ‘2020 도쿄<b>올림픽</b>’대회 로 32번째를 맞이한 <b>올림픽</b>대회입니다. 2020... ',
#    'bloggername': '인천광역시 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/incheontogi',
#    'postdate': '20210721'},
#   {'title': '이번 <b>올림픽</b>을 보며',
#    'link': 'https://blog.naver.com/ljb1202?Redirect=Log&logNo=222459619094',
#    'description': '<b>올림픽</b>이 한참 진행중에 있습니다. 말도 많고 탈도 많았지만 <b>올림픽</b>은 열렸습니다. 그로 인해 보기 싫어도 <b>올림픽</b>만 보여주니 볼 수밖에 없네요. 참고로 이번주에 갔을 게임장에서 난이도 하드로 클리어 한 제... ',
#    'bloggername': '천천히 꾸준히(Slow and Steady)',
#    'bloggerlink': 'https://blog.naver.com/ljb1202',
#    'postdate': '20210806'},
#   {'title': '[도쿄<b>올림픽</b> 여자배구 세르비아와의 동메달결정전]... ',
#    'link': 'https://blog.naver.com/dairyukem?Redirect=Log&logNo=222461571506',
#    'description': '#여자배구동메달결정전 #여자배구한국세르비아 #김연경<b>올림픽</b>마지막경기 오늘 아침 9시부터 도쿄<b>올림픽</b> 여자배구 동메달 결정전이 진행되었다. 조별예선에서 0 대 3으로 진 적이 있던 세르비아와의... ',
#    'bloggername': 'Riding on ::: [ 끄라스나야 스뜨렐랴 >)',
#    'bloggerlink': 'https://blog.naver.com/dairyukem',
#    'postdate': '20210808'},
#   {'title': '짝짝이 신발로 <b>올림픽</b> 금메달을 딴 선수, 짐 소프',
#    'link': 'https://bestan.tistory.com/1098',
#    'description': "사라진 <b>올림픽</b> 종목 ' 글의 미식축구 부문에서도 소개한 바 있다. ● 어린 시절 1887년 오클라호마 주... ● 짝짝이 신발로 금메달 1912년 스웨덴 스톡홀름 <b>올림픽</b>에서 짐 소프는 5종 경기에 참가해... ",
#    'bloggername': 'BesTan',
#    'bloggerlink': 'https://bestan.tistory.com/',
#    'postdate': '20210731'},
#   {'title': "[PRO'S BAG] 2020도쿄<b>올림픽</b> 금메달 장비, 넬리 코르다",
#    'link': 'https://blog.naver.com/cool2404?Redirect=Log&logNo=222461705038',
#    'description': '넬리 코르다(23세, 미국)가 2020 도쿄<b>올림픽</b> 골프 종목에서 금메달을 목에 걸었다. 넬리 코르다.... 넬리 코르다의 <b>올림픽</b> 금메달을 함께한 장비는 다음과 같다. 타이틀리스트 TSi2 3번우드 드라이버... ',
#    'bloggername': '노수성의 언더리페어',
#    'bloggerlink': 'https://blog.naver.com/cool2404',
#    'postdate': '20210808'},
#   {'title': '[2020도쿄<b>올림픽</b>]여자배구, 4강 일정 대한민국 vs 브라질',
#    'link': 'https://blog.naver.com/goldenlife?Redirect=Log&logNo=222458207813',
#    'description': '또한 조별 예선에서 일본에 승리한 김연경에 대해 “<b>올림픽</b>에 한 번 더 나오면 안 되냐”는 메시지를... 대한민국 여자배구 <b>올림픽</b> 대표팀 명단 내가 한국에 온 이유는 김연경이 주장이고, <b>올림픽</b>에 나갈 수... ',
#    'bloggername': 'k 스마트스토리',
#    'bloggerlink': 'https://blog.naver.com/goldenlife',
#    'postdate': '20210805'},
#   {'title': '도쿄 <b>올림픽</b> 펜싱 일정 경기 알고보기',
#    'link': 'https://blog.naver.com/iuwiqnknfdkaf?Redirect=Log&logNo=222456866463',
#    'description': '이번 도쿄 <b>올림픽</b> 펜싱 경기를 앞두고 있는 전웅태는 2018 자카르타 팔렘방 아시안게임 금메달... 8/7 15:45 남자 펜싱 한국 펜싱은 도쿄 <b>올림픽</b>에서 메달 5개를 수확했고 출전 사상 두번째로 좋은 성적을... ',
#    'bloggername': '비타민 라이프',
#    'bloggerlink': 'https://blog.naver.com/iuwiqnknfdkaf',
#    'postdate': '20210804'},
#   {'title': '여배와 함께한 뜨거운 여름이었다, 2020도쿄 <b>올림픽</b>... ',
#    'link': 'https://blog.naver.com/chany125?Redirect=Log&logNo=222461560898',
#    'description': '우리는 세트스코어 3:0으로 패하며 4위로 이번 2020 도쿄<b>올림픽</b>을 마무리했다. 2002 한일 월드컵 4강... 도쿄 <b>올림픽</b> 여자 배구 선수명단 우리 선수님들 이제 각자의 구단으로 돌아가실텐데 대체 누굴 응원 해야... ',
#    'bloggername': 'ThisIsChan',
#    'bloggerlink': 'https://blog.naver.com/chany125',
#    'postdate': '20210808'},
#   {'title': '도쿄<b>올림픽</b> 남여 마라톤 관전 후기(우승자의 신발들)',
#    'link': 'https://blog.naver.com/taxten?Redirect=Log&logNo=222461830022',
#    'description': '퓨마에서 카본 러닝화가 나온지도 모르고 있었는데 이 번 <b>올림픽</b>을 계기로 엄청난 홍보가 된 것 같다. 미국의 크로스컨트리 대표였다가 깜짝 신성으로 <b>올림픽</b> 출전권을 획득한 몰리 세이델과 스폰을... ',
#    'bloggername': 'Between Cynic and Optimist',
#    'bloggerlink': 'https://blog.naver.com/taxten',
#    'postdate': '20210808'},
#   {'title': '<b>올림픽</b> 근대5종 과 철인3종 차이점?',
#    'link': 'https://blog.naver.com/miho9000?Redirect=Log&logNo=222460325619',
#    'description': '최근 도쿄<b>올림픽</b> 때문에 어쩔 수 없이 보고는 있네요 근데 한 가지 궁금한 게 생겼어요 도대체 근대... &quot;근대 5종&quot;이라는 이름은 1912년 제5회 <b>올림픽</b> 경기 대회 때부터 정식종목으로 채택되었습니다. 경기... ',
#    'bloggername': 'B L O G ♥ H O L I C',
#    'bloggerlink': 'https://blog.naver.com/miho9000',
#    'postdate': '20210807'},
#   {'title': '2020 도쿄 <b>올림픽</b> 여자배구 대한민국 세르비아 동메달 결정전... ',
#    'link': 'https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222460524260',
#    'description': '<b>올림픽</b> 여자배구 준결승전 출처 : volleyballworld &amp; KOVO 인스타그램 8월 6일 금요일 밤 9시 경기 불금... 전력차이가 너무 커서 실망보다는 동메달결정전 잘 준비해서 김연경의 마지막 <b>올림픽</b> 후회없는 경기를... ',
#    'bloggername': '미스터모모 컬렉션',
#    'bloggerlink': 'https://blog.naver.com/mr_mo_mo',
#    'postdate': '20210807'},
#   {'title': '내 인생의 <b>올림픽</b>',
#    'link': 'https://blog.naver.com/suki5844?Redirect=Log&logNo=222459896368',
#    'description': '그런사이 시작된 <b>올림픽</b>, 시간 맞춰 볼 새도 없이 어느새 끝을 향해 달리고 있다. <b>올림픽</b>을 위해 수년간 몸과 마음을 수련하며 보냈을 선수들의 일과를 상상해 보니 마음이 너무 뭉클하다. 식빵언니 김연경의... ',
#    'bloggername': 'KinderJulie 킨더줄리',
#    'bloggerlink': 'https://blog.naver.com/suki5844',
#    'postdate': '20210806'},
#   {'title': 'Aug. <b>올림픽</b> 그리고 책 : 당신, 거기있어줄래요 / 그러라그래',
#    'link': 'https://blog.naver.com/rudgk753?Redirect=Log&logNo=222462320916',
#    'description': '8월 #<b>올림픽</b> 배구 <b>올림픽</b> 경기 때문에 심장이 쪼그라들었던 8월 ! 보는 내내 멋있다 멋있다만 수십번 말한 것 같다 배구도 그렇고 다른 경기들도 그렇고, 선수들 덕분에 즐거운 여름이었습니다 ♡ # 당신, 거기... ',
#    'bloggername': "MIN's 아날로그",
#    'bloggerlink': 'https://blog.naver.com/rudgk753',
#    'postdate': '20210809'},
#   {'title': '<b>올림픽</b>의 추억 10가지- <b>올림픽</b>의 문화적 코드',
#    'link': 'https://blog.naver.com/jhkim1909?Redirect=Log&logNo=222461579162',
#    'description': '<b>올림픽</b>은 최고의 글로벌 스포츠 경연장이고, 경제적 파급효과도 크지만 문화적인 코드의 공유, 관광을 통한 이문화 체험 등 다양한 요소를 반영하는 축제의 장이다. 필자는 <b>올림픽</b>에 열 번 참여했다. 기업... ',
#    'bloggername': '김주호의 PR의 힘',
#    'bloggerlink': 'https://blog.naver.com/jhkim1909',
#    'postdate': '20210808'},
#   {'title': '[2020 도쿄<b>올림픽</b>] 배구 국가대표 선수단。',
#    'link': 'https://blog.naver.com/lungs3?Redirect=Log&logNo=222461577888',
#    'description': '도쿄<b>올림픽</b> 여자배구 국가대표 선수단 2020 도쿄하계<b>올림픽</b> 대회 배구 대한민국 국가대표 명단 포지션별 선수 소개 # 레프트 Left (L) = 아웃사이드 히터 (Outside Hitter) 공수 모두 참여, 전위에서 공격... ',
#    'bloggername': '사고뭉치 레이첼 & 제멋대로 데이비드。♡',
#    'bloggerlink': 'https://blog.naver.com/lungs3',
#    'postdate': '20210808'},
#   {'title': '도쿄 <b>올림픽</b> 댓글에서 보이는 우리나라 집단의식의 변화',
#    'link': 'https://blog.naver.com/speralist?Redirect=Log&logNo=222460653035',
#    'description': '특히 이번 도쿄 <b>올림픽</b>을 보면서 우리나라 집단의식의 변화를 느낀다. 은메달을 딴 선수가 금메달을 따지 못해 죄송하다며 고개를 숙이는 모습. 그게 내가 어릴 적, 대한민국이 <b>올림픽</b>을 대하는 자세였다.... ',
#    'bloggername': '플로우 라이프, 애씀 없는 삶',
#    'bloggerlink': 'https://blog.naver.com/speralist',
#    'postdate': '20210807'},
#   {'title': '2021 도쿄 <b>올림픽</b> 여자 배구 8강전',
#    'link': 'https://blog.naver.com/apfhd8774?Redirect=Log&logNo=222456526935',
#    'description': '진짜 갓연경 빛연경님 멋있으셨다 9년만에 배구 <b>올림픽</b> 4강 진출 ✨ 대한민국 4강 진출!! <b>올림픽</b>에서 우리나라가 4강 진출한게 9년만이라고 한다 (❁´▽`❁) 최종 스코어 진짜 치열했다 특히 3세트도... ',
#    'bloggername': ':+:..*しоνё-Sтояу*..:+:',
#    'bloggerlink': 'https://blog.naver.com/apfhd8774',
#    'postdate': '20210804'},
#   {'title': '도쿄<b>올림픽</b> 다음 개최지, 2024년 어느나라에서 <b>올림픽</b>이... ',
#    'link': 'https://blog.naver.com/dmm_korea?Redirect=Log&logNo=222455365392',
#    'description': '도쿄<b>올림픽</b> 다음 개최지 안녕하세요. #엔구 #화상영어 입니다. 2021년, 뜨거운 여름을 더 뜨겁게 만들어주었던 도쿄<b>올림픽</b>이 마무리되어 가고 있습니다! 코로나 19로 인해 다사다난했지만... ',
#    'bloggername': '매일 25분, 엔구 화상영어',
#    'bloggerlink': 'https://blog.naver.com/dmm_korea',
#    'postdate': '20210806'},
#   {'title': '[재건축아파트 경매] 서울시 송파구 문정동 <b>올림픽</b>훼밀리타운... ',
#    'link': 'https://blog.naver.com/lauction?Redirect=Log&logNo=222461745217',
#    'description': '재건축아파트경매 송파구아파트 경매 <b>올림픽</b>훼밀리타운 (주)세종법률경매 배영식대표 입니다. 서울 재건축 아파트 경매 송팍구 문정동 가락시장역 <b>올림픽</b>훼밀리타운 아파트 48평 304동 801호 경매가 14억... ',
#    'bloggername': '경매만 20년 배소장',
#    'bloggerlink': 'https://blog.naver.com/lauction',
#    'postdate': '20210809'},
#   {'title': '2020 도쿄<b>올림픽</b> 여자 골프 관전 포인트',
#    'link': 'https://blog.naver.com/1429son?Redirect=Log&logNo=222457576503',
#    'description': '박인비, 고진영, 김세영, 김효주 이번 도쿄<b>올림픽</b>의 여자골프 참가 선수입니다 어벤저스로 불릴 만큼 막강한 실력의 선수들로 구성된 한국 여자골프 선수들인데요 세계 랭킹으로 출전 선수를 가린 <b>올림픽</b>... ',
#    'bloggername': '버튼홀의 도란도란 골프이야기',
#    'bloggerlink': 'https://blog.naver.com/1429son',
#    'postdate': '20210805'},
#   {'title': '34주 임산부 일상 ♩♪ 만삭사진 촬영, <b>올림픽</b>으로 태교하기',
#    'link': 'https://blog.naver.com/ryungna?Redirect=Log&logNo=222461928706',
#    'description': '폭풍 흡입해주겠어요..후 <b>올림픽</b>으로 태교했었는데 벌써 마지막 날 여자 배구 보면서 그렇게 뭉클하고 4강 신화가 여깄네요 전 야구를 좋아해서 프로야구 경기만 봤는데 이제 배구도 챙겨 볼 것 같아요ㅎㅎ... ',
#    'bloggername': '♥안녕 또안녕',
#    'bloggerlink': 'https://blog.naver.com/ryungna',
#    'postdate': '20210808'},
#   {'title': '2020 도쿄 <b>올림픽</b> 야구  국가대표팀 엔트리 및 예선경기 일정',
#    'link': 'https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222440885291',
#    'description': '말도 많았던 제 32회 도쿄<b>올림픽</b>이 드디어 시작하기 시작했습니다. 출처 : 네이버 출처 OSEN / 도쿄<b>올림픽</b>위원회 개막식은 7월 23일 금요일 20:00 - 23:30까지 도쿄 <b>올림픽</b> 스타디움에서 열릴 예정입니다. 야구는... ',
#    'bloggername': '미스터모모 컬렉션',
#    'bloggerlink': 'https://blog.naver.com/mr_mo_mo',
#    'postdate': '20210722'},
#   {'title': '알고보면 더 재미있는 제32회 도쿄<b>올림픽</b> 3탄! 안산 선수... ',
#    'link': 'https://blog.naver.com/dodreamgj?Redirect=Log&logNo=222449769184',
#    'description': '도쿄<b>올림픽</b> 개막 후 화재의 중심에 선 광주의 자랑! 세계 최고의 궁사 안산 선수! 알고 보면 더 재미있는 도쿄<b>올림픽</b> 3탄! 안산 선수를 만나볼까요? 연이은 금빛 메달 소식에 양궁 경기에 대한 열기가... ',
#    'bloggername': '광주광역시',
#    'bloggerlink': 'https://blog.naver.com/dodreamgj',
#    'postdate': '20210729'},
#   {'title': '[도쿄<b>올림픽</b> 소식] 한명목, 강윤희, 허광희, 이종준,  신승찬... ',
#    'link': 'https://blog.naver.com/mcstkorea?Redirect=Log&logNo=222458586880',
#    'description': '아쉽게 메달을 걸지 못하며 경기를 마무리한 한 선수, 파리<b>올림픽</b>에서 도전을 이어가겠다는 의사를... 무뚝뚝하시던 아버지의 사랑한다는 따뜻한 응원을 받으며 이번 <b>올림픽</b>이 첫 출전이자 마지막 출전이라는... ',
#    'bloggername': '도란도란 문화놀이터',
#    'bloggerlink': 'https://blog.naver.com/mcstkorea',
#    'postdate': '20210805'},
#   {'title': '도쿄<b>올림픽</b> 2020(2021) / 신희상',
#    'link': 'https://blog.naver.com/shinada?Redirect=Log&logNo=222446121734',
#    'description': '<b>올림픽</b> 순위에 태극기 대신에 저게 뭔지 집어 넣지를 않나 양궁 혼합 우승에서 명패에 태극기를 뒤집어... 도쿄<b>올림픽</b> 2020(2021) / 신희상 최악의 재난 장소 일본 도쿄<b>올림픽</b>에 출전한 대한민국 선수단 여러분... ',
#    'bloggername': '시와노래 (斗松)',
#    'bloggerlink': 'https://blog.naver.com/shinada',
#    'postdate': '20210726'},
#   {'title': '[톡톡! 글로벌] <b>올림픽</b>의 의미를 알아보고 즐기기',
#    'link': 'https://blog.naver.com/gcu2010?Redirect=Log&logNo=222459441882',
#    'description': '2020 도쿄 <b>올림픽</b>을 보면서 이러한 생각을 하는 분들이 꽤나 계실 텐데요. <b>올림픽</b>은 대체 언제부터 시작되었을까? <b>올림픽</b>의 오륜기는 무슨 의미일까? <b>올림픽</b>은 몇 년마다 개최되는 걸까? 여러 가지 의문점이... ',
#    'bloggername': '글로벌사이버대학교',
#    'bloggerlink': 'https://blog.naver.com/gcu2010',
#    'postdate': '20210806'},
#   {'title': '일본 vs 도미니카 여자 배구 25년만의 탈락(도쿄 <b>올림픽</b>) 코가... ',
#    'link': 'https://blog.naver.com/dline1secret?Redirect=Log&logNo=222454744757',
#    'description': '아라키의 마지막 <b>올림픽</b>이다. 주최국에서 패배 마음이 아플거다. 일본이 이번에 운이 없었다. 3세트는... 도쿄 <b>올림픽</b>은 2 일, 배구 여자 1 차 리그가 진행됐고 일본은 도미니카 공화국에 1-3로 패했다. 통산... ',
#    'bloggername': 'AI 우파 애널리스트',
#    'bloggerlink': 'https://blog.naver.com/dline1secret',
#    'postdate': '20210802'},
#   {'title': '실제로 존재한다면 반드시 캐나다가 우승할 <b>올림픽</b> 종목',
#    'link': 'https://blog.naver.com/wooriedu3?Redirect=Log&logNo=222459130408',
#    'description': '^^ 오늘은 캐나다에서 <b>올림픽</b>과 관련하여 재밌는 기사가 올라와서 해당내용을 공유해볼까 합니다. <b>올림픽</b>에 있었으면 캐나다가 우승할만한 종목 도쿄<b>올림픽</b>이 한창 진행중인 요즘인데요~ 현재 한국은... ',
#    'bloggername': '캐나다 전문! 우리에듀!',
#    'bloggerlink': 'https://blog.naver.com/wooriedu3',
#    'postdate': '20210806'},
#   {'title': '한국 일본 야구 중계 (<b>올림픽</b> 야구) 한일전',
#    'link': 'https://blog.naver.com/dydxodi333?Redirect=Log&logNo=222456803575',
#    'description': '김경문호가 이끄는 대한민국 <b>올림픽</b> 야구 대표팀은 오늘 일본을 꺽으면 7일 결승전에 진출하게... http://m.site.naver.com/0PWg7 <b>올림픽</b> 야구 한국 일본 중계는 위에서 보시면 되겠고 이제 두팀에 대해서 더 알아보는... ',
#    'bloggername': '당신의 리즈시절은',
#    'bloggerlink': 'https://blog.naver.com/dydxodi333',
#    'postdate': '20210804'},
#   {'title': '[강동구청역] &lt;오륜정&gt; 돼지갈비와 평양 냉면 <b>올림픽</b>공원... ',
#    'link': 'https://blog.naver.com/popo626?Redirect=Log&logNo=222462129328',
#    'description': '성내동쪽의 <b>올림픽</b>공원 가까이에 있는 집이다. 강동구청역과 가까움ㅎㅎ 인테리어가 옛날 식당들이 생각나는 그런 레트로풍의 식당 시설은 실제로는 새것인데 이런 액자들 때문에 뭔가 웅장한 느낌이 있음... ',
#    'bloggername': 'WANDERLUST ＊ 반더루스트',
#    'bloggerlink': 'https://blog.naver.com/popo626',
#    'postdate': '20210808'},
#   {'title': '무더위 속  <b>올림픽</b>경기 응원 .',
#    'link': 'https://blog.naver.com/ksn1665?Redirect=Log&logNo=222453136156',
#    'description': '의견에 <b>올림픽</b> 야구와 축구를 보면서 먹었는데.. 에궁.... 축구의 참패에 이어 야구까지 다행히 배구에서 김연경의 활약으로 승전보가 전해졌지요 무엇보다도 이번 <b>올림픽</b> 경기에 울 엄마가 관심이 많더군요... ',
#    'bloggername': '♪ Home sweet Home ☆',
#    'bloggerlink': 'https://blog.naver.com/ksn1665',
#    'postdate': '20210803'},
#   {'title': '도쿄 <b>올림픽</b>) 농구 경기장의 밤은 화기애애하다!',
#    'link': 'https://blog.naver.com/miuki73?Redirect=Log&logNo=222455687328',
#    'description': '도쿄 <b>올림픽</b>! 각 국가 대표 선수들의 활약이 코로나를 뚫고 금메달을 향해 달려가고 있습니다.. 비록... (반대로 여전히 경기장 주변의 오륜 반대, 중지 시위도 꾸준합니다...ㅠㅠ) <b>올림픽</b> 찬반 논란이 있는 만큼... ',
#    'bloggername': '일본에서 나답게 살아가는 이야기..',
#    'bloggerlink': 'https://blog.naver.com/miuki73',
#    'postdate': '20210803'},
#   {'title': '[관전평/한국:도미니카(8/7)] 결국은 실패로 마친 <b>올림픽</b>',
#    'link': 'https://blog.naver.com/gehrig395?Redirect=Log&logNo=222461631843',
#    'description': '대회 총평 되짚어 보면, 06 WBC - 08 <b>올림픽</b> - 09 WBC, 이 기간이 대표팀의 황금 시대였던 것 같습니다. 이... 이번에 <b>올림픽</b> 농구 무대에서 루이스 스콜라와 파우 가솔이 만 41세로 은퇴했지만, 이는... ',
#    'bloggername': "'야구'가 공용어입니다.",
#    'bloggerlink': 'https://blog.naver.com/gehrig395',
#    'postdate': '20210808'},
#   {'title': '<b>올림픽</b> 폐막식 선수분들 모두 수고 많으셨습니다 배구 양궁... ',
#    'link': 'https://blog.naver.com/minseon35?Redirect=Log&logNo=222462739240',
#    'description': '도쿄 <b>올림픽</b> 코로나 시국에 말도 많고 탈도 많았던 도쿄 <b>올림픽</b> 선수분들의 건강과 코로나로 걱정을 하며 노심초사 지켜보았네요 7/24-8/8일까지의 <b>올림픽</b> 기간이 막을 내렸어요 우선 우리 선수들과 세계의 모든... ',
#    'bloggername': '8 plus 8 studio',
#    'bloggerlink': 'https://blog.naver.com/minseon35',
#    'postdate': '20210809'},
#   {'title': '도쿄 <b>올림픽</b> 여자골프 1라운드 순위 및 중계방송 정보',
#    'link': 'https://blog.naver.com/beheaded?Redirect=Log&logNo=222457275601',
#    'description': '이번 2020 도쿄<b>올림픽</b> 남자골프 재미있게 보셨습니까? 정치적인 중립을 지키기 위해서 모자를 쓰지... 것이 <b>올림픽</b> 게임이지 않을까요? 수백만 달러의 상금이 걸린 미국 PGA 대회와 달리 <b>올림픽</b>은 개인의 명예와... ',
#    'bloggername': 'Golf for weekend warrior',
#    'bloggerlink': 'https://blog.naver.com/beheaded',
#    'postdate': '20210805'},
#   {'title': '<b>올림픽</b> 양궁 금메달 -끝-',
#    'link': 'https://blog.daum.net/sosa7469/15979157',
#    'description': "도쿄<b>올림픽</b>이 한창인 가운데, 네티즌들 사이에서 최고의 유행어로 손꼽히는 말이 있습니다. 바로 한국 양궁 국가대표 오진혁 선수의 '끝'입니다. 한국 양궁의 3관왕 여부가 달린 지난 7월 26일, 2020 도쿄<b>올림픽</b>... ",
#    'bloggername': '빛의세상 블로그',
#    'bloggerlink': 'https://blog.daum.net/sosa7469',
#    'postdate': '20210730'},
#   {'title': '잡다한 도쿄 <b>올림픽</b> 사이클링 소식 6편',
#    'link': 'https://blog.naver.com/piggybankm?Redirect=Log&logNo=222462891561',
#    'description': '도쿄 <b>올림픽</b>의 사이클링 관련 잡다한 소식 여섯번째 편입니다. 논란이 끊이지 않던 도쿄 <b>올림픽</b>. 이번에는 클라이밍의 볼더링 종목. 결승전의 가장 난이도 높은 마지막 문제 모양이 영.... 아무래도 일본의 국화... ',
#    'bloggername': 'piggybankm님의 블로그',
#    'bloggerlink': 'https://blog.naver.com/piggybankm',
#    'postdate': '20210809'},
#   {'title': '21.08.05-<b>올림픽</b>.. <b>올림픽</b> 뭐 그래요..',
#    'link': 'https://blog.naver.com/scampkjh?Redirect=Log&logNo=222458474114',
#    'description': "오래간만에 <b>올림픽</b> 공원 러닝. 불과 1,2주 전까지만 해도 더워서 걷기조차 힘들었는데 약간 눅눅한... 보고 '아 <b>올림픽</b> 기간이었지' 하는 게 실감이 난다. 희한하게 이번 <b>올림픽</b>만큼 크게 관심도 없고, 찾아보는... ",
#    'bloggername': 'JH',
#    'bloggerlink': 'https://blog.naver.com/scampkjh',
#    'postdate': '20210805'},
#   {'title': '2020 도쿄<b>올림픽</b> 폐막식, 메달 순위 결과',
#    'link': 'https://blog.naver.com/2vent6?Redirect=Log&logNo=222462200149',
#    'description': '2020 도쿄<b>올림픽</b> 폐막식입니다. 드디어 마감을 하네요. 7/23~8/8 17일간 벌어진 도쿄 <b>올림픽</b>... 말도 많고 탈도 많은 힘든 상황에서 시작되었지만 태풍피해도 없이 무탈히 잘 치뤄져서 정말 다행입니다.... ',
#    'bloggername': '.',
#    'bloggerlink': 'https://blog.naver.com/2vent6',
#    'postdate': '20210808'},
#   {'title': '8월 일상 덥다 <b>올림픽</b> 끝나 심심해지겠다..',
#    'link': 'https://blog.naver.com/irelsuga?Redirect=Log&logNo=222462933776',
#    'description': '헬스장 오면 <b>올림픽</b> 보는 재미에 런닝햇는데..이젠 뭘보나.... 새벽부터 방충망에 붙어서 울어재끼는 매미........ 궁뎅이 들썩거리면서 맴맴거리는거 극햠 진짜 왜자꾸 여기서 울고 잇는건지.. 6시부터... ',
#    'bloggername': '깐따삐야★',
#    'bloggerlink': 'https://blog.naver.com/irelsuga',
#    'postdate': '20210809'},
#   {'title': 'Marry me? <b>올림픽</b>공원 셀프웨딩촬영 / 셀프웨딩스냅',
#    'link': 'https://blog.naver.com/sun0h?Redirect=Log&logNo=222452153591',
#    'description': '조금씩 잎들도 색이 바뀌는 시기라 따스한 색감까지 있어 더 예쁜 거 같아요 ^^ 그럼 <b>올림픽</b>공원에서... 느낌은 <b>올림픽</b>공원이 좋답니다. Marry me? 가장 떨리는 순간이죠? 나와 결혼해줄래 ^^ 방울방울... ',
#    'bloggername': '사랑스냅 [SARANG SNAP]',
#    'bloggerlink': 'https://blog.naver.com/sun0h',
#    'postdate': '20210731'},
#   {'title': '<b>올림픽</b> 비공식종목?! <b>올림픽</b> 핀 트레이딩',
#    'link': 'https://blog.naver.com/ahepsmsrj?Redirect=Log&logNo=222455388344',
#    'description': '<b>올림픽</b> 같은 큰 국제대회의 핀을 모아서 자신의 핀과 다른사람이 갖고 있는 핀을 교환하는 문화 예요!! 이 글을 쓰게 된 이유 요즘 <b>올림픽</b> 영상들을 자주봤더니 유튜브의 알고리즘이 이번 도쿄 <b>올림픽</b> 에 참가한... ',
#    'bloggername': 'nado 소확행❤️',
#    'bloggerlink': 'https://blog.naver.com/ahepsmsrj',
#    'postdate': '20210803'},
#   {'title': '도쿄<b>올림픽</b> 야구에 6개국만 출전한 이유',
#    'link': 'https://blog.naver.com/africaphoto?Redirect=Log&logNo=222455197909',
#    'description': '2020 도쿄<b>올림픽</b> 야구에서 한국이 기사회생해서 일본과 경기를 앞두고 있습니다. 이번 야구를 보면... 도쿄<b>올림픽</b> 조직위원회가 개최국 지정 종목 중 하나로 야구를 꼽았기 때문인데요. 일본에서 프로야구가... ',
#    'bloggername': 'www.Africaphoto.net',
#    'bloggerlink': 'https://blog.naver.com/africaphoto',
#    'postdate': '20210803'},
#   {'title': '토쿄 <b>올림픽</b> 2021(야구)',
#    'link': 'https://blog.naver.com/kwansyk?Redirect=Log&logNo=222454270078',
#    'description': '무관중으로 열리고 있는 하계 &quot;#도쿄 <b>올림픽</b>&quot;이 중반에 들어섰다. 야구는 본선 2 라운드가 요코하마... 10위까지가 중국을 제외하면 선진국 일색이다.<b>올림픽</b>은 선진국만의 축제인가 하는 의구심이 든다. 세계의... ',
#    'bloggername': '해외영업전문가 박관식님의 블로그',
#    'bloggerlink': 'https://blog.naver.com/kwansyk',
#    'postdate': '20210802'},
#   {'title': '재수 없어도 살아남았다. (이탈리 판교/ <b>올림픽</b>배구/ 첫 뼈닭발)',
#    'link': 'https://blog.naver.com/mnschola?Redirect=Log&logNo=222461163580',
#    'description': '그리고 여자배구 <b>올림픽</b> 처음 보는 거였는데 계속 소름 돋고 눈물 찔끔 ㅠㅠ 미국이 브라질 부셔주라 그리고 배구 경기 끝나고 나서야 온 닭발은 이렇게 보니까 너무 혐오네오. 죄송함다.. 뼈 있는 닭발은... ',
#    'bloggername': '주로 돌아다니는, 인상 깊은 취미생활',
#    'bloggerlink': 'https://blog.naver.com/mnschola',
#    'postdate': '20210807'},
#   {'title': '7월 마지막주:집콕.<b>올림픽</b> 홀릭',
#    'link': 'https://blog.naver.com/eksksla?Redirect=Log&logNo=222455887995',
#    'description': '지금 <b>올림픽</b> 펜싱 결승전 한다고 당장 틀으라고 소리질러서 &quot;엥...언니 <b>올림픽</b> 챙겨보는 사람이었어?&quot; 라고 하며..하는수없이 틀었는데 내가 도리어 빠져버렸다!!!!!! 왜이렇게 잘하고 멋있고!!... ',
#    'bloggername': '소소한 행복이 더 소중해',
#    'bloggerlink': 'https://blog.naver.com/eksksla',
#    'postdate': '20210803'},
#   {'title': '[2020 도쿄<b>올림픽</b>] 정교한 기술력 : 골프',
#    'link': 'https://blog.naver.com/sports_7330?Redirect=Log&logNo=222456400198',
#    'description': '어느덧 끝을 향해 가고 있는 2020 도쿄<b>올림픽</b>인데요. 오늘은 2016 리우<b>올림픽</b>에서 <b>올림픽</b> 정식 종목으로 화려하게 복귀한 골프에 대해 알아보면서 우리나라 골프 국가대표 선수단에 대해 소개해드리는 시간... ',
#    'bloggername': '대한체육회 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/sports_7330',
#    'postdate': '20210804'},
#   {'title': '사진의 힘을 느끼게 한 MBC <b>올림픽</b> 개막식 논란',
#    'link': 'https://photohistory.tistory.com/19823',
#    'description': '제가 이 이야기를 왜 하냐면 MBC <b>올림픽</b> 개막식 논란을 보면서 MBC는 변한게 없는데 갑자기 전 세계에서 많은 욕을 먹고 있습니다. 몰상식한 MBC의 도쿄 <b>올림픽</b> 개막식 국가 소개 학예회 또는 장례식 같았다는... ',
#    'bloggername': '사진은 권력이다',
#    'bloggerlink': 'https://photohistory.tistory.com/',
#    'postdate': '20210726'},
#   {'title': '<b>올림픽</b> 금메달 연금 :: 메달리스트 혜택 알아보기',
#    'link': 'https://blog.naver.com/clbjhlove?Redirect=Log&logNo=222448188232',
#    'description': '처음에는 코로나인데 도쿄<b>올림픽</b> 해도 되는건가.. 걱정했다가 정작 <b>올림픽</b> 시작하니 ㅋㅋㅋ 게속 보게 되는 제 모습을 보게 됩니다. © kfdias, 출처 Unsplash 열심히 피땀 흘려서 자신의 노력으로 목에 메달을... ',
#    'bloggername': '일개미의 도시생활기',
#    'bloggerlink': 'https://blog.naver.com/clbjhlove',
#    'postdate': '20210728'},
#   {'title': '푹푹 찌는 날 해먹박 그리고 동경<b>올림픽</b> (20210724)',
#    'link': 'https://saiba.tistory.com/4532',
#    'description': '이웃나라 일본 동경에서 코로나 악조건속에서도 <b>올림픽</b>을 개최한다고 난리 부루스이다~!!! 각종... 동경<b>올림픽</b>을 즐감하면서 하룻밤을 보낸다ㅎㅎㅎ 그것으로 행복한 산님이 아니겠는가? ▼ 나름대론 발품... ',
#    'bloggername': 'saiba 流 아름다운 산행이야기',
#    'bloggerlink': 'https://saiba.tistory.com/',
#    'postdate': '20210726'},
#   {'title': '<b>올림픽</b> 정신으로',
#    'link': 'https://blog.naver.com/2myohyo?Redirect=Log&logNo=222458934700',
#    'description': "이 코시국에 '머선 <b>올림픽</b>'이냐고 생각했었다. 말도 안된다고 말이다. 하지만 늘 그렇듯 <b>올림픽</b>은 시작하면, 휴가내고 방구석 1열에 앉아 전종목을 관람하고 싶게 만드는 것이다. 규칙을 모르던 종목이 태반이나... ",
#    'bloggername': '아는언니가 용기내서 하는 블로그',
#    'bloggerlink': 'https://blog.naver.com/2myohyo',
#    'postdate': '20210806'},
#   {'title': '도쿄<b>올림픽</b> 축구대표팀 돌아보기 - 떠오르는 의문들 자문자답',
#    'link': 'https://blog.naver.com/tentama?Redirect=Log&logNo=222460960946',
#    'description': '메달을 기대했던 도쿄 <b>올림픽</b> 대한민국 축구대표팀은 장밋빛 기대와는 달리 8강에서 탈락하며 쓸쓸하게 마무리되었습니다. 가까운 나라에서 열리는 <b>올림픽</b>이었고 상대적으로 타 국가들에 비해 준비도 잘 된... ',
#    'bloggername': '녹색 도화지 위의 수채화',
#    'bloggerlink': 'https://blog.naver.com/tentama',
#    'postdate': '20210807'},
#   {'title': '먹방 찍다가 끝나버린 <b>올림픽</b> 축구',
#    'link': 'https://blog.naver.com/yousy1009?Redirect=Log&logNo=222454486461',
#    'description': '다들 주말은 뭐하셨나요 ㅋㅋㅋㅋㅋ 전 <b>올림픽</b>보며 신나게 먹방을 찍었답니다 먹다가 끝나버린 <b>올림픽</b> 축구ㅋㅋㅋㅋ 새우귀신이 있다보니 활새우가 나왔다니 바로 시켰지요 이른감이 있는데오 벌써 쑥쑥... ',
#    'bloggername': '알쏭달쏭~',
#    'bloggerlink': 'https://blog.naver.com/yousy1009',
#    'postdate': '20210802'},
#   {'title': '도쿄 <b>올림픽</b> 여자골프 3라운드 현재순위 및 4라운드 중계방송... ',
#    'link': 'https://blog.naver.com/beheaded?Redirect=Log&logNo=222459424327',
#    'description': '도쿄 <b>올림픽</b> 여자골프 오늘 3라운드가 끝났습니다. 흥미롭게 보셨는지요? 3라운드에서 우리선수들의... 자 도쿄<b>올림픽</b> 여자골프 3라운드 현재 순위를 한번 살펴보겠습니다. 1위는 3라운드에서도 랭킹을... ',
#    'bloggername': 'Golf for weekend warrior',
#    'bloggerlink': 'https://blog.naver.com/beheaded',
#    'postdate': '20210806'},
#   {'title': '2020 도쿄<b>올림픽</b> 폐막 후 가장 중요한 건 지속적인 관심',
#    'link': 'https://blog.naver.com/zenyoga01?Redirect=Log&logNo=222455658474',
#    'description': '지난 7월 22일 2020 도쿄 <b>올림픽</b>에 대한 이야기를 작성한 후 다시금 폐막 후에 관련된 이야기로 찾아온 젠요가하는 남자입니다. 다들 <b>올림픽</b> 재미나게 응원하고 계시죠? 물론, 아직 남은 경기가 많고... ',
#    'bloggername': '내 몸의 특별한 에너지, 젠요가',
#    'bloggerlink': 'https://blog.naver.com/zenyoga01',
#    'postdate': '20210803'},
#   {'title': '<b>올림픽</b> 여자배구 4강전 기적을 만들길',
#    'link': 'https://blog.naver.com/peterfine?Redirect=Log&logNo=222459283785',
#    'description': '<b>올림픽</b> 여자 배구 브라질 대표 선수 중 1명이 도핑검사에 양성이 나와 오늘 한국과의 준결승전에 출전하지 못한다. 게다가 지금 전수 조사 중인데 추가적으로 2명이 더 적발 될 경우 4강 자동탈락이다.... ',
#    'bloggername': '사색하는 자유(Truth will set you free)',
#    'bloggerlink': 'https://blog.naver.com/peterfine',
#    'postdate': '20210806'},
#   {'title': '도쿄<b>올림픽</b> 여자배구 4강 상대 브라질 확정, 야구 패자 준결승... ',
#    'link': 'https://blog.naver.com/zenyoga01?Redirect=Log&logNo=222457401361',
#    'description': '이번 도쿄 <b>올림픽</b>에서 그 어떤 종목보다 많은 분들이 사랑해 주시고 있고, 관심을 보여주시는 종목을 꼽자면 .. 역시나 터키를 꺾고 9년 만에 4강에 오른 2020 도쿄<b>올림픽</b> 여자배구가 아닌가 젠요가하는 남자... ',
#    'bloggername': '내 몸의 특별한 에너지, 젠요가',
#    'bloggerlink': 'https://blog.naver.com/zenyoga01',
#    'postdate': '20210805'},
#   {'title': '&lt;도핑의 과학&gt; : 역대 <b>올림픽</b> 포스터 엽서Set 증정 이벤트',
#    'link': 'https://blog.naver.com/dongnyokpub?Redirect=Log&logNo=222458089388',
#    'description': "<b>올림픽</b> 소식으로 뜨거운 요즘입니다~ 해마다 있는 이슈가 아니다보니 <b>올림픽</b>은 항상 특별한 경험으로 다가오는데요. <b>올림픽</b> 시즌을 기념하고자 '역대 <b>올림픽</b> 포스터 엽서' 를 기획하였습니다! 실물로 보았을... ",
#    'bloggername': '도서출판 동녘',
#    'bloggerlink': 'https://blog.naver.com/dongnyokpub',
#    'postdate': '20210805'},
#   {'title': 'J. 크루스도 <b>올림픽</b> 2체급 석권',
#    'link': 'https://blog.naver.com/doophong?Redirect=Log&logNo=222460689855',
#    'description': '크루스도 <b>올림픽</b> 2체급 석권 2020 도쿄 <b>올림픽</b> 헤비급 결승전에서 훌리오 세자르 라 크루스(31)가 2019년 세계선수권 우승자인 러시아의 무슬림 가지마고메도프(24)를 5-0의 판정으로 꺽고 2016 리우 데... ',
#    'bloggername': '토미의 복싱뉴스',
#    'bloggerlink': 'https://blog.naver.com/doophong',
#    'postdate': '20210807'},
#   {'title': '요즘 <b>올림픽</b>은 매 경기가 무슨 애니 한편 보는 느낌이네요',
#    'link': 'https://blog.naver.com/fjdkeivn?Redirect=Log&logNo=222455165785',
#    'description': '모든 선수들이 다 굉장했지만 역시 김연경 선수, 수비도 공격도 굉장하네요 무엇보다 주장으로서 자기 팀원들 멘탈을 케어해주면서 하는 모습이 굉장히 보기 좋았습니다 결론은 요즘 <b>올림픽</b> 보느라 휴가... ',
#    'bloggername': '세계가 평화롭기를',
#    'bloggerlink': 'https://blog.naver.com/fjdkeivn',
#    'postdate': '20210803'},
#   {'title': '2020 도쿄 <b>올림픽</b>- 서핑',
#    'link': 'https://blog.naver.com/rubystyle4?Redirect=Log&logNo=222454108529',
#    'description': '스톡홀름 <b>올림픽</b>에서 자신의 꿈을 처음 말했었는데 100년이 지난 후 드디어 그 꿈이 실현되었네요. 이번 도쿄 <b>올림픽</b>에는 스케이트보드, 스포츠클라이밍, 가라데, 야구와 함께 서핑을 포함해서 5개 종목이... ',
#    'bloggername': 'Always_Surfing_With_You',
#    'bloggerlink': 'https://blog.naver.com/rubystyle4',
#    'postdate': '20210802'},
#   {'title': '도쿄<b>올림픽</b> 개판소판, 사회적 수준 퇴행의 사례 - 골판지 침대... ',
#    'link': 'https://blog.naver.com/smoker3?Redirect=Log&logNo=222447708499',
#    'description': '현재 옆 나라 일본에서 도쿄 <b>올림픽</b>이 진행 중이다. 순수한 <b>올림픽</b>의 아마추어리즘 스포츠에는 관심이 생기지 않는다. 개판소판의 여러 가지 소식들이 관심을 끌 뿐이다. 경제적 수준과는 별개로 사회적 수준의... ',
#    'bloggername': '브레인렌탈(구 마켓ing)',
#    'bloggerlink': 'https://blog.naver.com/smoker3',
#    'postdate': '20210727'},
#   {'title': '<b>올림픽</b>의 역사 및 도쿄<b>올림픽</b> 경기 일정',
#    'link': 'https://blog.naver.com/suhyup_bank?Redirect=Log&logNo=222454203533',
#    'description': '아직 팬데믹 상황이지만, 어려운 상황에도 불구하고 전세계의 운동선수의 기량을 발휘할 도쿄<b>올림픽</b>이 개막되었습니다. 더위와 코로나에 지친 국민들에게 희망과 감동을 선사하는 <b>올림픽</b>인데요.... ',
#    'bloggername': 'Sh수협은행',
#    'bloggerlink': 'https://blog.naver.com/suhyup_bank',
#    'postdate': '20210803'},
#   {'title': '2020 도쿄 <b>올림픽</b> 여자농구 엔트리 및 예선 일정',
#    'link': 'https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222444884326',
#    'description': '박지수를 앞세운 여자농구대표팀이 2008년 베이징 이후 13년만의 <b>올림픽</b> 본선무대에 복귀했습니다. 출처 : 뉴시스 여자농구 <b>올림픽</b> 성적 출처 : 위키백과 대한민국 여자농구는 1984년 LA<b>올림픽</b>에서 박찬숙을... ',
#    'bloggername': '미스터모모 컬렉션',
#    'bloggerlink': 'https://blog.naver.com/mr_mo_mo',
#    'postdate': '20210725'},
#   {'title': '도쿄 <b>올림픽</b> 골프 현재 순위',
#    'link': 'https://blog.naver.com/sue21?Redirect=Log&logNo=222458069288',
#    'description': '<b>올림픽</b>의 열기가 뜨거운 이때 여자골프 경기에 많은 관심이 쏠리고 있습니다. 2016년 금메달을 목에 건... 여기서 2라운드가 마친 현재 시점의 <b>올림픽</b> 골프 순위를 확인해보겠습니다. 1위는 미국의 넬리 코다가... ',
#    'bloggername': '버디천재의 골프와 여행',
#    'bloggerlink': 'https://blog.naver.com/sue21',
#    'postdate': '20210805'},
#   {'title': '<b>올림픽</b> 야구 김경문호의  똥줄야구',
#    'link': 'https://blog.naver.com/so_sostory?Redirect=Log&logNo=222457623886',
#    'description': '2008년 베이징 <b>올림픽</b> 때 이야기다. 김경문 감독이 이끄는 우리나라 야구 국가대표팀은 결승에 오르기까지 내내 그런 야구를 하다가 최종적으로 금메달을 따면서 야구팬들이 그렇게 불렀다. 이번 도쿄 <b>올림픽</b>... ',
#    'bloggername': '소소한 이야기',
#    'bloggerlink': 'https://blog.naver.com/so_sostory',
#    'postdate': '20210805'},
#   {'title': '2020 도쿄 <b>올림픽</b> 여자배구... 브라질 김연경 마지막 <b>올림픽</b>',
#    'link': 'https://blog.naver.com/mr_mo_mo?Redirect=Log&logNo=222458341953',
#    'description': '런던 <b>올림픽</b> 이후 9년만에 <b>올림픽</b> 4강에 진출했고, 1976년 몬트리올 <b>올림픽</b> 동메달을 넘어 역대 최고의 성적올 올리기 위해서는 반드시 잡아야 할 상대 브라질과의 4강전이 8월 6일 금요일 21:00 열릴... ',
#    'bloggername': '미스터모모 컬렉션',
#    'bloggerlink': 'https://blog.naver.com/mr_mo_mo',
#    'postdate': '20210805'},
#   {'title': '<b>올림픽</b>경기시청 단기 공황장애',
#    'link': 'https://blog.naver.com/psy58psy?Redirect=Log&logNo=222457144648',
#    'description': '잘만 타면서 공황장애로 진짜 고생하는 환자들에겐 미안한 일이다 지금은 한일 야구전. 맥주, 과자, 체리와 함께 오늘 밤은 눈을 크게 뜨고 끝까지 #<b>올림픽</b>한일야구전 #<b>올림픽</b>한일배구전 #<b>올림픽</b>터키대한민국배구전',
#    'bloggername': '꼬까오랑캐꽃',
#    'bloggerlink': 'https://blog.naver.com/psy58psy',
#    'postdate': '20210804'},
#   {'title': '[일본미대/비다이] 2020 도쿄<b>올림픽</b> 픽토그램',
#    'link': 'https://blog.naver.com/musabi_art?Redirect=Log&logNo=222454102937',
#    'description': '지금 한창 말도많고 탈도 많은 도쿄<b>올림픽</b>이 열리고 있습니다. 1964년 도쿄<b>올림픽</b> 이후 57년만에 도쿄에서 열리는 <b>올림픽</b>인데요. 코로나19 여파로 인해 무관중으로 열리고 예년보다 <b>올림픽</b> 특수도 없는 적자... ',
#    'bloggername': '비다이 미술학원',
#    'bloggerlink': 'https://blog.naver.com/musabi_art',
#    'postdate': '20210802'},
#   {'title': '[2020 도쿄<b>올림픽</b>] 만능 스포츠맨으로 불리다 : 근대5종',
#    'link': 'https://blog.naver.com/sports_7330?Redirect=Log&logNo=222457696517',
#    'description': '오늘은 도쿄<b>올림픽</b> 종목인 근대5종과 대한민국 근대5종 국가대표 선수단에 대해 알려드립니다.... 다섯 가지로 이루어진 근대5종은 근대 <b>올림픽</b>의 창시자인 피에르 드 쿠베르탱 남작이 고안한 종목인데요.... ',
#    'bloggername': '대한체육회 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/sports_7330',
#    'postdate': '20210805'},
#   {'title': '도쿄<b>올림픽</b>의 쌍둥이 자매 선수들',
#    'link': 'https://bestan.tistory.com/1095',
#    'description': '도쿄<b>올림픽</b> 팀 종목에서는 결선에 진출하여 총점 163.638점으로 아쉽게 4위에 그쳤다. ● 샬롯... 시드니<b>올림픽</b> 동메달리스트 )에게서 운동을 배웠다. 2013년 14세의 나이로 프랑스 선수권에서... ',
#    'bloggername': 'BesTan',
#    'bloggerlink': 'https://bestan.tistory.com/',
#    'postdate': '20210728'},
#   {'title': '도쿄 <b>올림픽</b> 골프 박인비 일정 미리보기',
#    'link': 'https://blog.naver.com/y5q3dafgas?Redirect=Log&logNo=222454303414',
#    'description': '이번 도쿄 <b>올림픽</b> 골프 일정이 공식 시작되었는데요. 도쿄 인근 사이마타현 가와고에시에 위치한 골프장에는 <b>올림픽</b> 개막 이후에 여자골프는 이틀간 ᄍᆞᆲ은 연습라운드를 치르게 될 것으로 보여집니다.... ',
#    'bloggername': '콩가네 일기',
#    'bloggerlink': 'https://blog.naver.com/y5q3dafgas',
#    'postdate': '20210802'},
#   {'title': '도쿄 <b>올림픽</b> 개막식 일본인들 자체 평가및 평점',
#    'link': 'https://blog.naver.com/dline1secret?Redirect=Log&logNo=222443429535',
#    'description': '야구 마쯔이는 <b>올림픽</b>과 관계있었나? 어른 손 흔드는 사람들 필요없었다. 한기를 느꼈다. 코로나중 감동했다. 관중없어 실망 성화 주자 실망 코로나중 <b>올림픽</b> 관심없다 관중 절반은 넣었어야지 <b>올림픽</b>에 돈... ',
#    'bloggername': 'AI 우파 애널리스트',
#    'bloggerlink': 'https://blog.naver.com/dline1secret',
#    'postdate': '20210724'},
#   {'title': '[도쿄<b>올림픽</b> 소식] 김수지, 권하림, 안세현, 정혜정, 하지민... ',
#    'link': 'https://blog.naver.com/mcstkorea?Redirect=Log&logNo=222460601310',
#    'description': '이번 <b>올림픽</b>에서 한국 최초로 예산을 통과하고 준결승까지 오르며 대한민국 다이빙의 미래를 밝게 보여주었습니다. <b>올림픽</b>에 앞서 김 선수는 2019년 광주에서 열린 세계선수권 여자 1m 스프링보드에서 동메달을... ',
#    'bloggername': '도란도란 문화놀이터',
#    'bloggerlink': 'https://blog.naver.com/mcstkorea',
#    'postdate': '20210807'},
#   {'title': '<b>올림픽</b> 경기 보며 먹기 좋은 간식/베이글 칩 만들기',
#    'link': 'https://blog.naver.com/flowerddadam?Redirect=Log&logNo=222454860369',
#    'description': '<b>올림픽</b> 경기 보며 먹기 좋은 간식/베이글 칩 만들기 오늘은 비를 구경할 수 있어서 어제보단 낮춰진... 저는 요즘 <b>올림픽</b> 경기에 참여하는 대한민국 모든 선수들을 응원하고 있어요. 메달을 따든 따지 못하든... ',
#    'bloggername': '마음의 향기... 꽃따담',
#    'bloggerlink': 'https://blog.naver.com/flowerddadam',
#    'postdate': '20210802'},
#   {'title': '<b>올림픽</b>에서 가장 힘든 경기 종목 ? 수구,럭비,하키...',
#    'link': 'https://blog.naver.com/cipigs2?Redirect=Log&logNo=222456194101',
#    'description': '도쿄 <b>올림픽</b>에는 총33종목의 경기가 있습니다. 이 중, 가장 힘든 경기는 과연 무엇일까요? 이 전에 가장 편한 선수로는 조정의 콕스(COX)라는 선수가 가장 편하게 <b>올림픽</b> 경기를 하는 선수라고 포스팅을 했는데요... ',
#    'bloggername': '징기스칸과 킹콩',
#    'bloggerlink': 'https://blog.naver.com/cipigs2',
#    'postdate': '20210804'},
#   {'title': '<b>올림픽</b> 여자배구 결과: 세르비아에게 졌잘싸! 우리선수들... ',
#    'link': 'https://blog.naver.com/8winner?Redirect=Log&logNo=222461508966',
#    'description': '졌다고해도 태극마크걸고 경기하는 김연경선수의 마지막 <b>올림픽</b>경기를 실시간으로 응원할 수 있어서 후회는 없어요. 덧) 경기중에 식빵소리가 티비로 들려서 점수를 내줬지만 웃겼어요.역시 식빵언니... ',
#    'bloggername': '레슬리의 소소한 일상/리뷰 블로그✿',
#    'bloggerlink': 'https://blog.naver.com/8winner',
#    'postdate': '20210808'},
#   {'title': '시바우라공업대학 도쿄<b>올림픽</b> 메달 케이스 제작',
#    'link': 'https://blog.naver.com/u_hakseang?Redirect=Log&logNo=222454409073',
#    'description': '졸업생은 각 분야에서 다양한 활동을 이어가고 있는데요, 오늘은 도쿄<b>올림픽</b> 대회에 기여한 졸업생의 이야기를 소개합니다. 올해 세계적으로 가장 큰 행사는 바로 도쿄<b>올림픽</b> 일텐데요, <b>올림픽</b>의 꽃은 역시... ',
#    'bloggername': '일본유학 월간지! 월간 유학생',
#    'bloggerlink': 'https://blog.naver.com/u_hakseang',
#    'postdate': '20210802'},
#   {'title': '[<b>올림픽</b>] 도쿄 2020 - 2021년 8월 1일',
#    'link': 'https://blog.naver.com/sonofshb?Redirect=Log&logNo=222453672962',
#    'description': '어쩌다가 2020년 개최해야할 <b>올림픽</b>이 2021년 7월에서야 무관중으로 진행 중입니다. 안좋은 쪽으로... 우상혁 선수의 기록도 2m 31cm인데, <b>올림픽</b> 경기 중에 한국 신기록을 내다니 대단했습니다. 2.37m 1차를... ',
#    'bloggername': '건담과 함께하는 추억 만들기',
#    'bloggerlink': 'https://blog.naver.com/sonofshb',
#    'postdate': '20210801'},
#   {'title': '<b>올림픽</b> 종목 및 룰 소개',
#    'link': 'https://blog.naver.com/prnssc?Redirect=Log&logNo=222455267210',
#    'description': '&quot;대한민국, 파이팅!&quot; 전 세계를 뜨겁게 달구고 있는 도쿄<b>올림픽</b>이 한창 진행중인데요. 세계인의 축제, <b>올림픽</b>을 더욱 재미있고 깊이 있게 즐길 수 있는 방법! 바로 종목과 룰에 대해 자세히 아는 것 아닐까요.... ',
#    'bloggername': '원자력안전위원회 공식블로그',
#    'bloggerlink': 'https://blog.naver.com/prnssc',
#    'postdate': '20210803'},
#   {'title': '오사카생활 day.358 : 하루 늦게 보는 도쿄<b>올림픽</b> 개막식',
#    'link': 'https://blog.naver.com/mirr13?Redirect=Log&logNo=222458644397',
#    'description': '7.24.(토) - 오사카살이 358일째 어제 #Tokyo2020_<b>올림픽</b> 개막식이 있었는데요. 저희는 오카야마여행에서... be/GnZNal8s0Hc 그리고 유튜브 알고리즘 덕에 평창동계<b>올림픽</b> 개회식까지... ㅋㅋㅋ 아주 하루가... ',
#    'bloggername': '행복한 날(我 & 日) 만들기~*^^*',
#    'bloggerlink': 'https://blog.naver.com/mirr13',
#    'postdate': '20210806'},
#   {'title': '아름다운 경쟁과 협력,  과학기술 <b>올림픽</b> &quot;ITER 프로젝트&quot;',
#    'link': 'https://blog.naver.com/nfripr?Redirect=Log&logNo=222458129236',
#    'description': '세계인의 축제 <b>올림픽</b>의 열기가 뜨겁습니다. 코로나19라는 큰 위기 속에 치러지고 있지만 오랜 시간 이... 근대 <b>올림픽</b>의 창시자 쿠베르탱은 “<b>올림픽</b> 대회의 의의는 승리가 아니라 참가하는 데 있다”고... ',
#    'bloggername': 'FUSION Together',
#    'bloggerlink': 'https://blog.naver.com/nfripr',
#    'postdate': '20210805'},
#   {'title': '<b>올림픽</b> 3m 다이빙 우하람 선수',
#    'link': 'https://blog.naver.com/banaly?Redirect=Log&logNo=222456324848',
#    'description': '어제 저녁 식사를 하면서 TV를 봤는데, <b>올림픽</b> 3m 다이빙 결승이 하고 있었다. 도쿄 아쿠아틱스... 그리고 성장하는 것이 <b>올림픽</b>에서 가치있는 것이다. 우하람 선수가 4위라고 아쉬워하는 이들도 있을텐데... ',
#    'bloggername': '방바닥 블로그',
#    'bloggerlink': 'https://blog.naver.com/banaly',
#    'postdate': '20210804'},
#   {'title': '[2020 도쿄<b>올림픽</b>] 가장 무거운 메달에 도전!: 역도',
#    'link': 'https://blog.naver.com/sports_7330?Redirect=Log&logNo=222454230417',
#    'description': '2020 도쿄<b>올림픽</b>이 11일차에 접어들었습니다. 순수하게 운동만을 바라보며 <b>올림픽</b>을 준비한 한국 국가대표팀들의 출전 소식과 메달 소식이 들려오는데요. 이번 <b>올림픽</b>에 첫 도전을 하는 루키들이 참여해서... ',
#    'bloggername': '대한체육회 공식 블로그',
#    'bloggerlink': 'https://blog.naver.com/sports_7330',
#    'postdate': '20210802'},
#   {'title': '아카이브전시로 30년 전 88 서울<b>올림픽</b>의 추억을 느껴보자!',
#    'link': 'https://blog.naver.com/ungsblue?Redirect=Log&logNo=222456973176',
#    'description': '우리나라 최초 <b>올림픽</b>의 아카이브 홍대 전시 코로나 팬데믹으로 인해 1년 밀려버린 도쿄 <b>올림픽</b> 2020. 무관중 경기에 일부 선수들의 참가 거부로 인하여 흥행이 저조할 줄 알았는데, 우리나라 선수들의... ',
#    'bloggername': '크리에이티브를 위한 축적의 시간',
#    'bloggerlink': 'https://blog.naver.com/ungsblue',
#    'postdate': '20210805'}]}

# %%
search_df
# Out:
#                             bloggerlink               bloggername  \
# 0    https://blog.naver.com/jylee062700                       블로그
# 1      https://blog.naver.com/dongi0508       Der Sinn des Lebens
# 2       https://blog.naver.com/beheaded  Golf for weekend warrior
# 3        https://blog.naver.com/mosfnet               기획재정부 경제e야기
# 4       https://blog.naver.com/shalacho                      보미로그
# ..                                  ...                       ...
# 195       https://blog.naver.com/mirr13     행복한 날(我 & 日) 만들기~*^^*
# 196       https://blog.naver.com/nfripr           FUSION Together
# 197       https://blog.naver.com/banaly                   방바닥 블로그
# 198  https://blog.naver.com/sports_7330              대한체육회 공식 블로그
# 199     https://blog.naver.com/ungsblue         크리에이티브를 위한 축적의 시간
#
#                                            description  \
# 0    드디어 16일간의 올림픽이 끝이 났다..! 재미없겠지만 잘 봐줘.. https://...
# 1    여자배구 올림픽 일정 A조 세계랭킹 순위 한일전! 오늘 진짜 여러 빅매치들이 많이 ...
# 2    멋진 골프스윙과 흠잡을 데 없는 플레이로 이번 도쿄 올림픽을 빛내준 낼리코다 선수,...
# 3    영화 &lt;우리 생애 최고의 순간&gt;(이하 우생순)은 2004년 아테네 올림픽...
# 4    도쿄 올림픽 야구 대표팀의 동메달 획득을 원하는 사람은 얼마나 될까요? 솔직히 말해...
# ..                                                 ...
# 195  7.24.(토) - 오사카살이 358일째 어제 #Tokyo2020_올림픽 개막식이 ...
# 196  세계인의 축제 올림픽의 열기가 뜨겁습니다. 코로나19라는 큰 위기 속에 치러지고 있...
# 197  어제 저녁 식사를 하면서 TV를 봤는데, 올림픽 3m 다이빙 결승이 하고 있었다. ...
# 198  2020 도쿄올림픽이 11일차에 접어들었습니다. 순수하게 운동만을 바라보며 올림픽을...
# 199  우리나라 최초 올림픽의 아카이브 홍대 전시 코로나 팬데믹으로 인해 1년 밀려버린 도...
#
#                                                   link    p_Date  \
# 0    https://blog.naver.com/jylee062700?Redirect=Lo...  20210808
# 1    https://blog.naver.com/dongi0508?Redirect=Log&...  20210731
# 2    https://blog.naver.com/beheaded?Redirect=Log&l...  20210808
# 3    https://blog.naver.com/mosfnet?Redirect=Log&lo...  20210809
# 4    https://blog.naver.com/shalacho?Redirect=Log&l...  20210807
# ..                                                 ...       ...
# 195  https://blog.naver.com/mirr13?Redirect=Log&log...  20210806
# 196  https://blog.naver.com/nfripr?Redirect=Log&log...  20210805
# 197  https://blog.naver.com/banaly?Redirect=Log&log...  20210804
# 198  https://blog.naver.com/sports_7330?Redirect=Lo...  20210802
# 199  https://blog.naver.com/ungsblue?Redirect=Log&l...  20210805
#
#                                             title
# 0                                 8월 8일 올림픽 최종 결산
# 1                     여자배구 올림픽 일정 A조 세계랭킹 순위 한일전!
# 2                    올림픽 여자골프 금메달리스트 넬리코다 선수 골프클럽
# 3         영화 &lt;우리 생애 최고의 순간&gt;으로 보는 올림픽 메달과 연금
# 4                            [올림픽 야구] 세계 최강이라는 거품
# ..                                            ...
# 195            오사카생활 day.358 : 하루 늦게 보는 도쿄올림픽 개막식
# 196  아름다운 경쟁과 협력,  과학기술 올림픽 &quot;ITER 프로젝트&quot;
# 197                             올림픽 3m 다이빙 우하람 선수
# 198               [2020 도쿄올림픽] 가장 무거운 메달에 도전!: 역도
# 199             아카이브전시로 30년 전 88 서울올림픽의 추억을 느껴보자!
#
# [200 rows x 6 columns]
