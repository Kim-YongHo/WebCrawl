# %% [markdown]
# ## selenium 패키지 모듈 이용한 자동 크롤링
# - webdriver라는 API를 통해 운영체제에 설치된 웹 브라우저를 제어하는 함수를 포함한 패키지
# - 써드파티라이브러리이기 때문에 설치 해 줘야 함
# - prompt 에서 설치
#     - pip install selenium

# %% [markdown]
# ## 크롬 드라이버 다운로드
# - https://chromedriver.chromium.org/downloads
#
# ## 크롬 정보 확인
# - 메뉴 - 도움말 - 크롬정보

# %%
#동적 생성되는 data 크롤링
#Selenium 모듈 사용
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen
from selenium import webdriver

# %%
#크롬 드라이버를 통한 네이버 접속
from selenium.webdriver.chrome.options import Options 
from selenium.webdriver.chrome.options import Options 
options = Options() 
options.binary_location= 'C:/Program Files/Google/Chrome/Application/chrome.exe' 

driver = webdriver.Chrome("./driver/chromedriver",chrome_options = options)
driver.get("https://news.naver.com")
# Out:
# <ipython-input-2-efa9dda3d421>:7: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome("./driver/chromedriver",chrome_options = options)

# %%
# webdriver 객체 생성
driver =webdriver.Chrome('./driver/chromedriver')
# 페이지 접근
url ='https://nid.naver.com/nidlogin.login' 
driver.get(url)

# %%
# 화면 캡쳐
driver.save_screenshot('./crawl_data/sshot.png')
# Out:
# True

# %% [markdown]
# ## 세레니움을 이용한 동적 크롤링 순서
# 1. webdriver 객체 생성
#     - webdriver.브라우저 명 (웹드라이버 경로/path=)
# 2. get(url) 메서드 이용해서 사이트에 문서를 요청 후 응답 반환
# 3. 접근한 페이지 소스코드 추출
#     - driver.page_source
# 4. 소스 코드를 파서기에 적용시켜 추출

# %% [markdown]
# ## 동적 로그인 진행
# - 프로그램 코드를 통해서 자동 로그인 가능하게 브라우저 제어

# %%
# webdriver 객체 생성
driver =webdriver.Chrome('./driver/chromedriver')
# 페이지 접근
url ='https://nid.naver.com/nidlogin.login' 
driver.get(url)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# id 값을 전달

driver.find_element_by_id('id') # 자바스크립트에 존재 특정한 위치에 포커 맞춰줌

# 1. id를 입력할 element(input tag)를 찾아야 함 - input type = 'text' id='id'
id_elem = driver.find_element_by_id('id')

#2. 미리 입력된 값이 있을 경우 값 지우기
id_elem.clear() ## 값 clear 기능

# 3. send_keys() 함수를 이용해서 element 값 전달
id_elem.send_keys('testtmkm0515') ## 값을 전송하는 함수 (아이디 값을 전달)

# %%
# PW 값을 전달

# 1. id를 입력할 element(input tag)를 찾아야 함 - input type = 'text' id='id'
pw_elem = driver.find_element_by_id('pw')

#2. 미리 입력된 값이 있을 경우 값 지우기
pw_elem.clear() ## 값 clear 기능

# 3. send_keys() 함수를 이용해서 element 값 전달
pw_elem.send_keys('kdigital1234@') ## 값을 전송하는 함수 (아이디 값을 전달)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 로그인 버튼 클릭
xpath = '//*[@id="log.login"]'
driver.find_element_by_xpath(xpath).click()

# %% [markdown]
# - 봇으로 인식할 경우 하기와 같은 화면 나올 수 있음
# ![image.png](attachment:image.png)

# %%
## 자동입력 방지 문자를 우회하기 위해 브라우저 종료 후
## send_keys() 함수 대신 id/pass 값을 input 박스에 직접 value로 대입하는 스크립트 코드 작성 후 실해
id_input = 'testmkm0515'
pw_input = 'kdigital1234@'

"docoument.getElementsByName('id')[0].value='" + id_input+"'" # 자바스크립트 코드
# Out:
# "docoument.getElementsByName('id')[0].value='testmkm0515'"

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
# 연결이 끊키면 다시 연결
driver = webdriver.Chrome('./driver/chromedriver')
url ='https://nid.naver.com/nidlogin.login'

driver.get(url)

# %% [markdown]
# ## webdriver 통해 script 코드 직접 실행
# - driver.execute_script() 함수 - driver로 script 코드를 직접 실행

# %%
#id input tag의 value 값으로 id_input 변수 저장 값 대입 코드 실행

driver.execute_script("document.getElementsByName('id')[0].value='" + id_input+"'")
driver.execute_script("document.getElementsByName('pw')[0].value='" + id_input+"'")

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
## 로그인 버튼 클릭 (보안 상 수동으로 로그인 하기!)
xpath = '//*[@id="log.login"]'
driver.find_element_by_xpath(xpath).click()

# %%
# 메일 페이지로 접근
driver.get('http://mail.naver.com')

# %%
# 코드 추출
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser') ### 해당 파일 들어와야 확인 가능

# %%
soup.head()
# Out:
# [<meta content="IE=edge" http-equiv="X-UA-Compatible"/>,
#  <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>,
#  <link href="/css/mail2_le.min.210729.css" rel="stylesheet" type="text/css"/>,
#  <link href="/css/mail_skin.min.210729.css" rel="stylesheet" type="text/css"/>,
#  <link href="//ssl.pstatic.net" rel="dns-prefetch"/>,
#  <link href="//lcs.naver.com" rel="dns-prefetch"/>,
#  <link href="//cc.naver.com" rel="dns-prefetch"/>,
#  <link href="//static.nid.naver.com" rel="dns-prefetch"/>,
#  <link href="//phinf.pstatic.net" rel="dns-prefetch"/>,
#  <link href="/css/mail_me.min.210729.css" rel="stylesheet" type="text/css"/>,
#  <link href="/favicon.ico?2" rel="shortcut icon"/>,
#  <title>받은메일함(14) : 네이버 메일</title>,
#  <script type="text/javascript">
#
#
#
#  		var gnb_service = "mail";
#  		var gnb_logout = "http://www.naver.com";
#  		var gnb_template = "gnb_utf8";
#  		var gnb_brightness = 3;
#  		var gnb_item_hide_option = 8;
#  		var gnb_one_naver = 1;
#
#
# ...

# %% [markdown]
# ### 메일 보낸이를 표현하는 div tag
#  -`<div class="name _ccr(lst.from) ">` <b> `<span class="blind">보낸 이:</span>` </b> `<a title="&quot;네이버&quot; <webmaster@naver.com>" class="_c1(myContextMenu|showSenderContextLayer|list|2) _stopDefault" href="#">네이버</a></div>`

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
raw_list = soup.find_all('div',{'class':"name _ccr(lst.from)"})
raw_list
# Out:
# [<div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|3682) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|3681) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|3680) _stopDefault" href="#" title='"vvspearlvvs" &lt;noreply@github.com&gt;'>vvspearlvvs</a></div>,
#  <div class="name _ccr(lst.from)"><span class="blind">보낸 이:</span><a class="_c1(myContextMenu|showSenderContextLayer|list|3679) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a></div>,
# ...

# %%
[raw_list[n].find('a') for n in range(0, len(raw_list))]
# Out:
# [<a class="_c1(myContextMenu|showSenderContextLayer|list|3682) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a>,
#  <a class="_c1(myContextMenu|showSenderContextLayer|list|3681) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a>,
#  <a class="_c1(myContextMenu|showSenderContextLayer|list|3680) _stopDefault" href="#" title='"vvspearlvvs" &lt;noreply@github.com&gt;'>vvspearlvvs</a>,
#  <a class="_c1(myContextMenu|showSenderContextLayer|list|3679) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a>,
#  <a class="_c1(myContextMenu|showSenderContextLayer|list|3678) _stopDefault" href="#" title='"네이버" &lt;account_noreply@navercorp.com&gt;'>네이버</a>,
#  <a class="_c1(myContextMenu|showSenderContextLayer|list|3677) _stopDefault" href="#" title='"현대오토에버" &lt;noreply@hyundai-autoever.recruiter.co.kr&gt;'>현대오토에버</a>,
# ...

# %%
send_list = [raw_list[n].find('a').get_text() for n in range(0, len(raw_list))]
send_list
# Out:
# ['네이버',
#  '네이버',
#  'vvspearlvvs',
#  '네이버',
#  '네이버',
#  '현대오토에버',
#  '네이버',
#  '현대오토에버',
#  '네이버',
#  '네이버',
#  '네이버',
#  'GitHub',
#  'GitHub',
#  '네이버',
#  'GitHub',
#  '멀티캠퍼스',
#  '네이버',
#  '멀티캠퍼스',
#  '네이버',
#  '현대모비스',
#  '웹민원센터',
#  '웹민원센터',
#  '웹민원센터',
#  '현대모비스',
#  '프로그래머스',
#  'LG전자',
#  'SSAFY 최지웅 교수',
#  '민채원',
#  'ashore',
#  '포스코채용팀']
