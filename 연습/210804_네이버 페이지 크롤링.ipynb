# %%
import requests
from bs4 import BeautifulSoup
import bs4
from urllib.request import urlopen

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
headers = {'User-Agent':
           "Mozilla/5.0(Window NT 10.0;Win64;x64) AppleWebKit/537.36 (KHTML,likeGecko) Chrome/87.0.4280.88 Safari/537.36"}
url = "https://news.naver.com/main/read.naver?mode=LPOD&mid=sec&oid=001&aid=0012578115&isYeonhapFlash=Y&rc=N"

# %%
result = requests.get(url, headers=headers)

# %%
## 응답 정상여부 확인
#  (응답성공 : 200, 응답오류 : 400번대 코드, 500번대 코드 : 서버오륲)
result
# Out:
# <Response [200]>

# %%
bs_obj = BeautifulSoup(result.content, 'html.parser')

# %%
bs_obj.text
# Out:
# '\n\n\n\n\n\n\n오후 6시까지 전국서 1천475명 확진…어제보다 50명 많아 : 네이버 뉴스\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n메인 메뉴로 바로가기\n본문으로 바로가기\n\n\n\n\n\n\n\n\n\n\nNAVER\n뉴스\n\n\n\nTV연예\n스포츠\n뉴스스탠드\n날씨\n프리미엄\n\n\n\n\n\n\n\n\n\n\n뉴스홈 \n속보\n정치 \n경제 \n사회 \n생활/문화 \n세계 \nIT/과학 \n오피니언 \n포토 \nTV \n랭킹뉴스 \n\n\n\n뉴스 검색\n\n\n\n\n검색\n\n\n\n\n\n\n08.04(수)\n\n\n팩트체크\n\n\n\n언론사 설정\n\n\n\n언론사 뉴스\n\n\n\n라이브러리\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nPICK\n안내\n\n\n해당 언론사가 주요기사로직접 선정한 기사입니다.\n언론사 편집판 바로가기\n닫기\n\n\n\n\n오후 6시까지 전국서 1천475명 확진…어제보다 50명 많아\n\n\r\n\r\n\t\r\n\t\r\n\r\n\r\n기사입력 2021.08.04. 오후 6:49\r\n\r\n\r\n\r\n\t\r\n\t\t최종수정 2021.08.04. 오후 7:21\n\n기사원문\n스크랩\n\n\n\n\n\n\n본문듣기\n\n\n\n설정\n\n\n\n성별 선택하기\n\n선택된 성별남성\n여성\n\n\n\n속도 선택하기\n\n느림\n선택된 속도보통\n빠름\n\n\n설정을 저장하시겠습니까?\n확인\n취소\n\n\n\n\n\n\n\n\n\n\n좋아요\n\n좋아요 평가하기\n공감\n\n\n\n\n좋아요\n0\n\n\n\n\n훈훈해요\n0\n\n\n\n\n슬퍼요\n0\n\n\n\n\n화나요\n0\n\n\n\n\n후속기사 원해요\n0\n\n\n\n\n\n댓글\n\n\n\n\n요약봇\n\n\n본문 요약봇도움말\n자동 추출 기술로 요약된 내용입니다. 요약 기술의 특성상 본문의 
# ...

# %%
bs_obj.find('span', {'class':'t11'})
# Out:
# <span class="t11">2021.08.04. 오후 6:49</span>
